# %% [markdown]
# # 판다스 기초
# - pandas는 통상 pd로 import하고
# - 수치해석적 함수가 많은 numpy는 통상 np로 import 한다.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Pandas의 데이터형을 구성하는 기본은 Series이다.
# - index와 value로 이루어져 있다.
# - 한 가지 데이터 타입만 가질 수 있다.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
pd.Series([1, 3, 5, np.nan, 6, 8], dtype = str)
# Out:
# 0      1
# 1      3
# 2      5
# 3    NaN
# 4      6
# 5      8
# dtype: object

# %% [markdown]
# ### 날짜와 시간을 이용

# %%
dates = pd.date_range('20240421', periods = 6) # 2024년 4월 21일 부터 6일간 이란 의미
dates
# Out:
# DatetimeIndex(['2024-04-21', '2024-04-22', '2024-04-23', '2024-04-24',
#                '2024-04-25', '2024-04-26'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ## DataFrame
# - pd.Series()
#     - index, value
# - pd.DataFrame()
#     - index, value, colum

# %% [markdown]
# ### 넘파이를 이용한 데이터 프레임 생성
# - 판다스에서 가장 많이 사용되는 데이터형은 DataFrame이다.
# - index와 colunms를 지정하면 된다.
#
# ### 랜덤 함수를 이용해 6행 4열 데이터프레임 만들기
# - 변수명 = pd.DataFrame(np.random.randn(6, 4), index = dates, colunms = ['A', 'B', 'C', 'D'])

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
# 앞 5개만 조회
df.head()
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488

# %%
# 뒤 5개 조회
df.tail()
# Out:
#                    A         B         C         D
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
# index만 조회
df.index
# Out:
# DatetimeIndex(['2024-04-21', '2024-04-22', '2024-04-23', '2024-04-24',
#                '2024-04-25', '2024-04-26'],
#               dtype='datetime64[ns]', freq='D')

# %%
# colunms만 조회
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# value만 조회
df.values
# Out:
# array([[ 0.96169372, -0.95707971, -0.13773051,  1.52702343],
#        [-1.46591329, -0.31345187,  0.91838064, -0.06317563],
#        [ 1.61646728,  0.68052198,  1.09705017, -0.65743437],
#        [-0.2355579 , -0.27010259,  0.6014425 ,  0.50978278],
#        [ 0.16207205,  1.42850832,  0.94381231, -0.4164878 ],
#        [ 0.66979367,  0.41127592,  1.48623874,  1.64488967]])

# %%
# DataFrame의 기본 정보 확인
# 여기서는 각 컬럼의 크기와 데이터 형태를 확인하는 경우가 많다
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2024-04-21 to 2024-04-26
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      float64
#  1   B       6 non-null      float64
#  2   C       6 non-null      float64
#  3   D       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0 bytes

# %%
# DataFrame의 통계적 기본 정보 확인
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.284759  0.163279  0.818199  0.424100
# std    1.070568  0.848545  0.549661  0.982634
# min   -1.465913 -0.957080 -0.137731 -0.657434
# 25%   -0.136150 -0.302615  0.680677 -0.328160
# 50%    0.415933  0.070587  0.931096  0.223304
# 75%    0.888719  0.613210  1.058741  1.272713
# max    1.616467  1.428508  1.486239  1.644890

# %% [markdown]
# ## 데이터 정렬 : sort_values
# - df.sort_values(by = 'B', ascending = False)  # ascending = False : 내림차순으로 정렬.

# %%
df.sort_values(by = 'B', ascending = False)  # ascending = False : 내림차순으로 정렬.
# Out:
#                    A         B         C         D
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-26  0.669794  0.411276  1.486239  1.644890
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023

# %% [markdown]
# ## 데이터 선택

# %%
# 특정 컬럼만 읽기
df['A']
# Out:
# 2024-04-21    0.961694
# 2024-04-22   -1.465913
# 2024-04-23    1.616467
# 2024-04-24   -0.235558
# 2024-04-25    0.162072
# 2024-04-26    0.669794
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# ## offset index
# - [n:m] : n 부터 m - 1 까지
# - 그러나 인덱스나 컬럼의 이름으로 slice하는 경우는 끝을 포함

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434

# %%
# 인덱스 이름으로 슬라이스 한경우 끝이 포함되는걸 볼 수 있음
df['20240423':'20240426']
# Out:
#                    A         B         C         D
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %% [markdown]
# ## pandas slice - option loc
# - loc : location
# - index 이름으로 특정 행, 열을 선택 한다.
# - 이름으로도 사용 가능
# - pandas의 보편적인 slice 옵션

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
# loc 함수를 사용할 때는 항상 [인덱스 설정 , 컬럼 설정]
df.loc[:,['A', 'B']] # :, 모든 인덱스 중에 ['A', 'B'] A,B 컬럼에 해당하는 자료를 선택해줘
# Out:
#                    A         B
# 2024-04-21  0.961694 -0.957080
# 2024-04-22 -1.465913 -0.313452
# 2024-04-23  1.616467  0.680522
# 2024-04-24 -0.235558 -0.270103
# 2024-04-25  0.162072  1.428508
# 2024-04-26  0.669794  0.411276

# %%
df.loc['20240423':'20240426',['A', 'B']]
# Out:
#                    A         B
# 2024-04-23  1.616467  0.680522
# 2024-04-24 -0.235558 -0.270103
# 2024-04-25  0.162072  1.428508
# 2024-04-26  0.669794  0.411276

# %%
df.loc['20240423',['A', 'B']]
# Out:
# A    1.616467
# B    0.680522
# Name: 2024-04-23 00:00:00, dtype: float64

# %%
df.loc['20240421':'20240423',['A', 'D']]
# Out:
#                    A         D
# 2024-04-21  0.961694  1.527023
# 2024-04-22 -1.465913 -0.063176
# 2024-04-23  1.616467 -0.657434

# %% [markdown]
# ## pandas slice - option iloc
# - iloc : inter location
#     - 컴퓨터가 인식하는 인덱스 값
# - iloc 옵션을 이용해서 번호로만 접근

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df.iloc[3]
# Out:
# A   -0.235558
# B   -0.270103
# C    0.601442
# D    0.509783
# Name: 2024-04-24 00:00:00, dtype: float64

# %%
df.iloc[3, 2]
# Out:
# 0.6014424961440628

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2024-04-24 -0.235558 -0.270103
# 2024-04-25  0.162072  1.428508

# %%
df.iloc[[1, 2, 4], [0,2]]
# Out:
#                    A         C
# 2024-04-22 -1.465913  0.918381
# 2024-04-23  1.616467  1.097050
# 2024-04-25  0.162072  0.943812

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2024-04-21 -0.957080 -0.137731
# 2024-04-22 -0.313452  0.918381
# 2024-04-23  0.680522  1.097050
# 2024-04-24 -0.270103  0.601442
# 2024-04-25  1.428508  0.943812
# 2024-04-26  0.411276  1.486239

# %% [markdown]
# ## pandas slice under condition
# - df[condition]과 같이 사용하는 것이 일반적
# - pandas의 버전에 따라 조금씩 허용되는 문법이 다르다.
# - 인터넷에서 확보한 소스코드를 돌릴 때는 pandas의 버전을 확인하는 것이 필요하다.

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df[df['A'] > 0] # df의 'A'컬럼에서 0보다 큰 경우만 보여줘
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df[df > 0]  # 전체에 대한 조건을 입력 시 조건에 해당하지 않는 값은 NaN 처리가 된다.
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694       NaN       NaN  1.527023
# 2024-04-22       NaN       NaN  0.918381       NaN
# 2024-04-23  1.616467  0.680522  1.097050       NaN
# 2024-04-24       NaN       NaN  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812       NaN
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %% [markdown]
# ## 컬럼 추가
# - 기존 컬럼이 없으면 추가
# - 기존 컬럼이 있으면 수정

# %%
df['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df
# Out:
#                    A         B         C         D      E
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023    one
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176    one
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434    two
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783  three
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488   four
# 2024-04-26  0.669794  0.411276  1.486239  1.644890  three

# %%
# 특정 요소가 있는지 확인
df['E'].isin(['two', 'four'])       # 있으면 True 없으면 False가 나옴
# Out:
# 2024-04-21    False
# 2024-04-22    False
# 2024-04-23     True
# 2024-04-24    False
# 2024-04-25     True
# 2024-04-26    False
# Freq: D, Name: E, dtype: bool

# %%
# 특정 요소가 있는 행만 선택할 때는 전체에 중괄호 씌우고 앞에 변수명을 적어준다.
df[df['E'].isin(['two', 'four'])] # True 값만 선택됨
# Out:
#                    A         B         C         D     E
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434   two
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488  four

# %% [markdown]
# ## 특정 컬럼 제거

# %%
df
# Out:
#                    A         B         C         D      E
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023    one
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176    one
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434    two
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783  three
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488   four
# 2024-04-26  0.669794  0.411276  1.486239  1.644890  three

# %%
del df['E']
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df.drop(['D','C'], axis = 1) # axis = 0 : 가로 , axis = 1 : 세로
# Out:
#                    A         B
# 2024-04-21  0.961694 -0.957080
# 2024-04-22 -1.465913 -0.313452
# 2024-04-23  1.616467  0.680522
# 2024-04-24 -0.235558 -0.270103
# 2024-04-25  0.162072  1.428508
# 2024-04-26  0.669794  0.411276

# %%
df.drop(['20240421'])
# Out:
#                    A         B         C         D
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %% [markdown]
# ## Pandas apply function
# - apply : 함수를 적용

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
df['A'].apply('sum')
# Out:
# 1.7085555304522482

# %%
df['A'].apply('mean')
# Out:
# 0.2847592550753747

# %%
df['A'].apply('min'),df['A'].apply('max')
# Out:
# (-1.4659132900846215, 1.6164672770592432)

# %%
# 각 컬럼 누적 합
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -0.504220 -1.270532  0.780650  1.463848
# 2024-04-23  1.112248 -0.590010  1.877700  0.806413
# 2024-04-24  0.876690 -0.860112  2.479143  1.316196
# 2024-04-25  1.038762  0.568396  3.422955  0.899708
# 2024-04-26  1.708556  0.979672  4.909194  2.544598

# %%
df['A'].apply(np.std)
# Out:
# 2024-04-21    0.0
# 2024-04-22    0.0
# 2024-04-23    0.0
# 2024-04-24    0.0
# 2024-04-25    0.0
# 2024-04-26    0.0
# Freq: D, Name: A, dtype: float64

# %%
df['A'].apply(np.sum)
# Out:
# 2024-04-21    0.961694
# 2024-04-22   -1.465913
# 2024-04-23    1.616467
# 2024-04-24   -0.235558
# 2024-04-25    0.162072
# 2024-04-26    0.669794
# Freq: D, Name: A, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2024-04-21  0.961694 -0.957080 -0.137731  1.527023
# 2024-04-22 -1.465913 -0.313452  0.918381 -0.063176
# 2024-04-23  1.616467  0.680522  1.097050 -0.657434
# 2024-04-24 -0.235558 -0.270103  0.601442  0.509783
# 2024-04-25  0.162072  1.428508  0.943812 -0.416488
# 2024-04-26  0.669794  0.411276  1.486239  1.644890

# %%
def plusMinus(num):
    return 'plus' if num > 0 else 'minus'

# %%
df['A'].apply(plusMinus)
# Out:
# 2024-04-21     plus
# 2024-04-22    minus
# 2024-04-23     plus
# 2024-04-24    minus
# 2024-04-25     plus
# 2024-04-26     plus
# Freq: D, Name: A, dtype: object

# %%
df['A'].apply(lambda num: 'plus' if num > 0 else 'minus')
# Out:
# 2024-04-21     plus
# 2024-04-22    minus
# 2024-04-23     plus
# 2024-04-24    minus
# 2024-04-25     plus
# 2024-04-26     plus
# Freq: D, Name: A, dtype: object

# %% [markdown]
# ## 4. 두 데이터 합치기

# %% [markdown]
# #### Pandas에서 데이터 프레임을 병합하는 방법
# - pd.concat()
# - pd.merge()
# - pd.join()

# %%
# 딕셔너리 안의 리스트 형태
left = pd.DataFrame({
    'key' : ['K0', 'K4','K2', 'K3'],
    'A' : ['A0', 'A1', 'A2', 'A3'],
    'B' : ['B0', 'B1', 'B2', 'B3']
})
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K4  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
# 리스트 안의 딕셔너리 형태
right = pd.DataFrame([
    {'key':'K0', 'C':'C0', 'D':'D0'},
    {'key':'K1', 'C':'C1', 'D':'D1'},
    {'key':'K2', 'C':'C2', 'D':'D2'},
    {'key':'K3', 'C':'C3', 'D':'D3'}
])
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# #### pd.merge()
# - 두 데이터 프레임에서 컬럼이나 인텍스를 기준으로 잡고 병합하는 방법
# - 기준이 되는 컬럼이나 인덱스를 키값이라고 한다.
# - 기준이 되는 키 값은 두 데이터 프레임에 모두 포함되어 있어야 한다.

# %%
pd.merge(left, right, how = 'inner', on = 'key') # how = 'inner' 가 디폴트 값이다.
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(left, right, how = 'left', on = 'key')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K4  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(left, right, how = 'right', on = 'key')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(left, right, how = 'outer', on = 'key')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K4   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
url = 'https://en.wikipedia.org/wiki/FIFA_World_Cup'

# %%
df = pd.read_html(url)
df
# Out:
# [                         0                                                  1
#  0                      NaN                                                NaN
#  1          Organising body                                               FIFA
#  2                  Founded                                 1930; 94 years ago
#  3                   Region                                      International
#  4          Number of teams                          32 (48 from 2026 onwards)
#  5     Related competitions  FIFA Women's World Cup FIFA U-20 World Cup FIF...
#  6        Current champions                       Argentina (3rd title) (2022)
#  7  Most successful team(s)                                  Brazil (5 titles)
#  8                  Website                                   Official website,
#                                                     0
#  0                   Argentina, the current champions
#  1                                        Tournaments
#  2  1930 1934 1938 1950 1954 1958 1962 1966 1970 1...,
#                                         Confederation  Total  \
#  0                 Asian Football Confederation (AFC)      2
#  1            Confederation of African Football (CAF)      2
#  2  Confederation of North, Central America and Ca...      4
#  3   South American Football Confederation (CONMEBOL)      5
#  4               Oceania Football Confederation (OFC)      0
#  5     Union of European Football Associations (UEFA)     12
#  6     Two competitions cancelled due to World War II      0
#
#                                                 Hosts
#  0  2002: South Korea, Japan 2022: Qatar 2034: Sau...
#  1                   2010: South Africa 2030: Morocco
#  2  1970: Mexico 1986: Mexico 1994: United States ...
#  3  1930: Uruguay 1950: Brazil 1962: Chile 1978: A...
#  4                                                NaN
#  5  1934: Italy 1938: France 1954: Switzerland 195...
#  6                                          1942 1946  ,
#           Year                          Hosts Venues/ Cities  \
#           Year                          Hosts Venues/ Cities
#  0        1930                        Uruguay            3/1
#  1        1934                          Italy            8/8
#  2        1938                         France           10/9
#  3        1950                         Brazil            6/6
#  4        1954                    Switzerland            6/6
#  5        1958                         Sweden          12/12
#  6        1962                          Chile            4/4
#  7        1966                        England            8/7
#  8        1970                         Mexico            5/5
#  9        1974                   West Germany            9/9
#  10       1978                      Argentina            6/5
#  11       1982                          Spain          17/14
#  12       1986                         Mexico          12/11
#  13       1990                          Italy          12/12
#  14       1994                  United States            9/9
#  15       1998                         France          10/10
#  16       2002             South Korea  Japan          20/20
#  17       2006                        Germany          12/12
#  18       2010                   South Africa           10/9
#  19       2014                         Brazil          12/12
#  20       2018                         Russia          12/11
#  21       2022                          Qatar            8/5
#  22       2026  Canada  Mexico  United States          16/16
#  23  2030[n 1]       Morocco  Portugal  Spain            NaN
#  24       2034                   Saudi Arabia            NaN
#  25    Overall                        Overall        Overall
#
#     Total attendance † Matches Average attendance Highest attendances ‡  \
#     Total attendance † Matches Average attendance                Number
#  0            590549.0      18            32808.0                 93000
#  1            363000.0      17            21353.0                 55000
#  2            375700.0      18            20872.0                 58455
#  3           1045246.0      22            47511.0           173,850[96]
#  4            768607.0      26            29562.0                 63000
#  5            819810.0      35            23423.0                 50928
#  6            893172.0      32            27912.0                 68679
#  7           1563135.0      32            48848.0                 98270
#  8           1603975.0      32            50124.0                108192
#  9           1865753.0      38            49099.0                 83168
#  10          1545791.0      38            40679.0                 71712
#  11          2109723.0      52            40572.0                 95500
#  12          2394031.0      52            46039.0                114600
#  13          2516215.0      52            48389.0                 74765
#  14          3587538.0      52            68991.0                 94194
#  15          2785100.0      64            43517.0                 80000
#  16          2705197.0      64            42269.0                 69029
#  17          3359439.0      64            52491.0                 72000
#  18          3178856.0      64            49670.0                 84490
#  19          3429873.0      64            53592.0                 74738
#  20          3031768.0      64            47371.0                 78011
#  21          3404252.0      64            53191.0                 88966
#  22                NaN     104                NaN                   NaN
#  23                NaN     104                NaN                   NaN
#  24                NaN     104                NaN                   NaN
#  25         43936730.0     964            45577.0           173,850[96]
#
#                                               \
#                                        Venue
#  0            Estadio Centenario, Montevideo
#  1                Stadio Nazionale PNF, Rome
#  2              Olympique de Colombes, Paris
#  3          Maracanã Stadium, Rio de Janeiro
#  4                    Wankdorf Stadium, Bern
#  5                Ullevi Stadium, Gothenburg
#  6                Estadio Nacional, Santiago
#  7                   Wembley Stadium, London
#  8               Estadio Azteca, Mexico City
#  9                    Olympiastadion, Munich
#  10         Estadio Monumental, Buenos Aires
#  11                      Camp Nou, Barcelona
#  12              Estadio Azteca, Mexico City
#  13                          San Siro, Milan
#  14          Rose Bowl, Pasadena, California
#  15             Stade de France, Saint-Denis
#  16   International Stadium, Yokohama, Japan
#  17                   Olympiastadion, Berlin
#  18                Soccer City, Johannesburg
#  19         Maracanã Stadium, Rio de Janeiro
#  20                 Luzhniki Stadium, Moscow
#  21                    Lusail Stadium, Qatar
#  22                                      NaN
#  23                                      NaN
#  24                                      NaN
#  25  Maracanã Stadium, Rio de Janeiro (1950)
#
#
#                                                Game(s)
#  0                  Uruguay 6–1 Yugoslavia, semi-final
#  1                     Italy 2–1 Czechoslovakia, final
#  2                     France 1–3 Italy, quarter-final
#  3                  Brazil 1–2 Uruguay, deciding match
#  4                     West Germany 3–2 Hungary, final
#  5                Brazil 2–0 Soviet Union, group stage
#  6                        Brazil 4–2 Chile, semi-final
#  7                     England 4–2 West Germany, final
#  8                     Mexico 1–0 Belgium, group stage
#  9                 West Germany 1–0 Chile, group stage
#  10                   Italy 1–0 Argentina, group stage
#  11               Argentina 0–1 Belgium, Opening match
#  12  Mexico 1–1 Paraguay, group stage Argentina 3–2...
#  13           West Germany 4–1 Yugoslavia, group stage
#  14                     Brazil 0–0 (3–2p) Italy, final
#  15                           Brazil 0–3 France, final
#  16                          Brazil 2–0 Germany, final
#  17        Germany 1–1 (4–2p) Argentina, quarter-final
#  18                       Spain 1–0 Netherlands, final
#  19                       Germany 1–0 Argentina, final
#  20                          France 4–2 Croatia, final
#  21                 Argentina 3–3 (4–2p) France, final
#  22                                                NaN
#  23                                                NaN
#  24                                                NaN
#  25                                                NaN  ,
#     Ed.       Year                                Host  \
#     Ed.       Year                                Host
#  0    1       1930                             Uruguay
#  1    2       1934                               Italy
#  2    3       1938                              France
#  3    –       1942  (Not held because of World War II)
#  4    –       1946  (Not held because of World War II)
#  5    4       1950                              Brazil
#  6    5       1954                         Switzerland
#  7    6       1958                              Sweden
#  8    7       1962                               Chile
#  9    8       1966                             England
#  10   9       1970                              Mexico
#  11  10       1974                        West Germany
#  12  11       1978                           Argentina
#  13  12       1982                               Spain
#  14  13       1986                              Mexico
#  15  14       1990                               Italy
#  16  15       1994                       United States
#  17  16       1998                              France
#  18  17       2002                  South Korea  Japan
#  19  18       2006                             Germany
#  20  19       2010                        South Africa
#  21  20       2014                              Brazil
#  22  21       2018                              Russia
#  23  22       2022                               Qatar
#  24  23       2026       Canada  Mexico  United States
#  25  24  2030[n 1]            Morocco  Portugal  Spain
#  26  25       2034                        Saudi Arabia
#
#                                   Final                                      \
#                                Champion                               Score
#  0                              Uruguay                                 4–2
#  1                                Italy                        2–1 (a.e.t.)
#  2                                Italy                                 4–2
#  3   (Not held because of World War II)  (Not held because of World War II)
#  4   (Not held because of World War II)  (Not held because of World War II)
#  5                              Uruguay                           2–1 [n 3]
#  6                         West Germany                                 3–2
#  7                               Brazil                                 5–2
#  8                               Brazil                                 3–1
#  9                              England                        4–2 (a.e.t.)
#  10                              Brazil                                 4–1
#  11                        West Germany                                 2–1
#  12                           Argentina                        3–1 (a.e.t.)
#  13                               Italy                                 3–1
#  14                           Argentina                                 3–2
#  15                        West Germany                                 1–0
#  16                              Brazil                0–0 (a.e.t.) (3–2 p)
#  17                              France                                 3–0
#  18                              Brazil                                 2–0
#  19                               Italy                1–1 (a.e.t.) (5–3 p)
#  20                               Spain                        1–0 (a.e.t.)
#  21                             Germany                        1–0 (a.e.t.)
#  22                              France                                 4–2
#  23                           Argentina                3–3 (a.e.t.) (4–2 p)
#  24                                 NaN                                 NaN
#  25                                 NaN                                 NaN
#  26                                 NaN                                 NaN
#
#                                                        Third-place play-off  \
#                               Runner-up                               Third
#  0                            Argentina                       United States
#  1                       Czechoslovakia                             Germany
#  2                              Hungary                              Brazil
#  3   (Not held because of World War II)  (Not held because of World War II)
#  4   (Not held because of World War II)  (Not held because of World War II)
#  5                               Brazil                              Sweden
#  6                              Hungary                             Austria
#  7                               Sweden                              France
#  8                       Czechoslovakia                               Chile
#  9                         West Germany                            Portugal
#  10                               Italy                        West Germany
#  11                         Netherlands                              Poland
#  12                         Netherlands                              Brazil
#  13                        West Germany                              Poland
#  14                        West Germany                              France
#  15                           Argentina                               Italy
#  16                               Italy                              Sweden
#  17                              Brazil                             Croatia
#  18                             Germany                              Turkey
#  19                              France                             Germany
#  20                         Netherlands                             Germany
#  21                           Argentina                         Netherlands
#  22                             Croatia                             Belgium
#  23                              France                             Croatia
#  24                                 NaN                                 NaN
#  25                                 NaN                                 NaN
#  26                                 NaN                                 NaN
#
#                                                                              \
#                                   Score                              Fourth
#  0                              – [n 2]                          Yugoslavia
#  1                                  3–2                             Austria
#  2                                  4–2                              Sweden
#  3   (Not held because of World War II)  (Not held because of World War II)
#  4   (Not held because of World War II)  (Not held because of World War II)
#  5                            3–1 [n 3]                               Spain
#  6                                  3–1                             Uruguay
#  7                                  6–3                        West Germany
#  8                                  1–0                          Yugoslavia
#  9                                  2–1                        Soviet Union
#  10                                 1–0                             Uruguay
#  11                                 1–0                              Brazil
#  12                                 2–1                               Italy
#  13                                 3–2                              France
#  14                        4–2 (a.e.t.)                             Belgium
#  15                                 2–1                             England
#  16                                 4–0                            Bulgaria
#  17                                 2–1                         Netherlands
#  18                                 3–2                         South Korea
#  19                                 3–1                            Portugal
#  20                                 3–2                             Uruguay
#  21                                 3–0                              Brazil
#  22                                 2–0                             England
#  23                                 2–1                             Morocco
#  24                                 NaN                                 NaN
#  25                                 NaN                                 NaN
#  26                                 NaN                                 NaN
#
#                            No. of teams
#                            No. of teams
#  0                                   13
#  1                                   16
#  2                                   15
#  3   (Not held because of World War II)
#  4   (Not held because of World War II)
#  5                                   13
#  6                                   16
#  7                                   16
#  8                                   16
#  9                                   16
#  10                                  16
#  11                                  16
#  12                                  16
#  13                                  24
#  14                                  24
#  15                                  24
#  16                                  24
#  17                                  32
#  18                                  32
#  19                                  32
#  20                                  32
#  21                                  32
#  22                                  32
#  23                                  32
#  24                                  48
#  25                                  48
#  26                                  48  ,
#                 Team                            Titles  \
#  0            Brazil  5 (1958, 1962, 1970, 1994, 2002)
#  1          Germany1       4 (1954, 1974*, 1990, 2014)
#  2             Italy       4 (1934*, 1938, 1982, 2006)
#  3         Argentina             3 (1978*, 1986, 2022)
#  4            France                   2 (1998*, 2018)
#  5           Uruguay                   2 (1930*, 1950)
#  6           England                         1 (1966*)
#  7             Spain                          1 (2010)
#  8       Netherlands                               NaN
#  9           Hungary                               NaN
#  10  Czech Republic2                               NaN
#  11           Sweden                               NaN
#  12          Croatia                               NaN
#  13           Poland                               NaN
#  14          Austria                               NaN
#  15         Portugal                               NaN
#  16          Belgium                               NaN
#  17    United States                               NaN
#  18            Chile                               NaN
#  19           Turkey                               NaN
#  20          Serbia3                               NaN
#  21          Russia4                               NaN
#  22         Bulgaria                               NaN
#  23      South Korea                               NaN
#  24          Morocco                               NaN
#
#                      Runners-up                  Third place  \
#  0              2 (1950*, 1998)               2 (1938, 1978)
#  1   4 (1966, 1982, 1986, 2002)  4 (1934, 1970, 2006*, 2010)
#  2               2 (1970, 1994)                    1 (1990*)
#  3         3 (1930, 1990, 2014)                          NaN
#  4               2 (2006, 2022)               2 (1958, 1986)
#  5                          NaN                          NaN
#  6                          NaN                          NaN
#  7                          NaN                          NaN
#  8         3 (1974, 1978, 2010)                     1 (2014)
#  9               2 (1938, 1954)                          NaN
#  10              2 (1934, 1962)                          NaN
#  11                   1 (1958*)               2 (1950, 1994)
#  12                    1 (2018)               2 (1998, 2022)
#  13                         NaN               2 (1974, 1982)
#  14                         NaN                     1 (1954)
#  15                         NaN                     1 (1966)
#  16                         NaN                     1 (2018)
#  17                         NaN                     1 (1930)
#  18                         NaN                    1 (1962*)
#  19                         NaN                     1 (2002)
#  20                         NaN                          NaN
#  21                         NaN                          NaN
#  22                         NaN                          NaN
#  23                         NaN                          NaN
#  24                         NaN                          NaN
#
#              Fourth place  Top 4 total
#  0        2 (1974, 2014*)           11
#  1               1 (1958)           13
#  2               1 (1978)            8
#  3                    NaN            6
#  4               1 (1982)            7
#  5   3 (1954, 1970, 2010)            5
#  6         2 (1990, 2018)            3
#  7               1 (1950)            2
#  8               1 (1998)            5
#  9                    NaN            2
#  10                   NaN            2
#  11              1 (1938)            4
#  12                   NaN            3
#  13                   NaN            2
#  14              1 (1934)            2
#  15              1 (2006)            2
#  16              1 (1986)            2
#  17                   NaN            1
#  18                   NaN            1
#  19                   NaN            1
#  20        2 (1930, 1962)            2
#  21              1 (1966)            1
#  22              1 (1994)            1
#  23             1 (2002*)            1
#  24              1 (2022)            1  ,
#    Confederation  AFC  CAF  CONCACAF  CONMEBOL  OFC  UEFA  Total
#  0         Teams   43   49        46        89    4   258    489
#  1        Top 16    9   11        15        37    1    99    172
#  2         Top 8    2    4         5        36    0   105    152
#  3         Top 4    1    1         1        23    0    62     88
#  4         Top 2    0    0         0        15    0    29     44
#  5           4th    1    1         0         5    0    15     22
#  6           3rd    0    0         1         3    0    18     22
#  7           2nd    0    0         0         5    0    17     22
#  8           1st    0    0         0        10    0    12     22,
#      Rank             Player  Goals  Matches  Goals per game
#  0      1     Miroslav Klose     16       24            0.67
#  1      2            Ronaldo     15       19            0.84
#  2      3        Gerd Müller     14       13            1.08
#  3      4      Just Fontaine     13        6            2.17
#  4      4       Lionel Messi     13       26            0.50
#  5      6      Kylian Mbappé     12       14            0.86
#  6      6               Pelé     12       14            0.86
#  7      8      Sándor Kocsis     11        5            2.20
#  8      8   Jürgen Klinsmann     11       17            0.65
#  9     10        Helmut Rahn     10       10            1.00
#  10    10  Gabriel Batistuta     10       12            0.83
#  11    10       Gary Lineker     10       12            0.83
#  12    10   Teófilo Cubillas     10       13            0.77
#  13    10      Thomas Müller     10       19            0.53
#  14    10      Grzegorz Lato     10       20            0.50,
#     Rank National team  Goals scored
#  0     1        Brazil           237
#  1     2       Germany           232
#  2     3     Argentina           152
#  3     4        France           136
#  4     5         Italy           128
#  5     6         Spain           108
#  6     7       England           104
#  7     8   Netherlands            96
#  8     9       Uruguay            89
#  9    10       Hungary            87,
#                   World Cup          Golden Ball  \
#  0             1930 Uruguay          Not Awarded
#  1               1934 Italy          Not Awarded
#  2              1938 France          Not Awarded
#  3              1950 Brazil          Not Awarded
#  4         1954 Switzerland          Not Awarded
#  5              1958 Sweden          Not Awarded
#  6               1962 Chile          Not Awarded
#  7             1966 England          Not Awarded
#  8              1970 Mexico          Not Awarded
#  9        1974 West Germany          Not Awarded
#  10          1978 Argentina          Not Awarded
#  11              1982 Spain          Paolo Rossi
#  12             1986 Mexico       Diego Maradona
#  13              1990 Italy  Salvatore Schillaci
#  14      1994 United States              Romário
#  15             1998 France              Ronaldo
#  16  2002 South Korea/Japan          Oliver Kahn
#  17            2006 Germany      Zinedine Zidane
#  18       2010 South Africa         Diego Forlán
#  19             2014 Brazil         Lionel Messi
#  20             2018 Russia          Luka Modrić
#  21              2022 Qatar         Lionel Messi
#
#                                            Golden Boot  Goals  \
#  0                                   Guillermo Stábile      8
#  1                                     Oldřich Nejedlý      5
#  2                                            Leônidas      7
#  3                                              Ademir      8
#  4                                       Sándor Kocsis     11
#  5                                       Just Fontaine     13
#  6   Flórián Albert  Garrincha  Vavá  Valentin Ivan...      4
#  7                                             Eusébio      9
#  8                                         Gerd Müller     10
#  9                                       Grzegorz Lato      7
#  10                                       Mario Kempes      6
#  11                                        Paolo Rossi      6
#  12                                       Gary Lineker      6
#  13                                Salvatore Schillaci      6
#  14                     Oleg Salenko  Hristo Stoichkov      6
#  15                                        Davor Šuker      6
#  16                                            Ronaldo      8
#  17                                     Miroslav Klose      5
#  18                                      Thomas Müller      5
#  19                                    James Rodríguez      6
#  20                                         Harry Kane      6
#  21                                      Kylian Mbappé      8
#
#            Golden Glove  Clean sheets FIFA Young Player Award  \
#  0          Not Awarded           NaN             Not Awarded
#  1          Not Awarded           NaN             Not Awarded
#  2          Not Awarded           NaN             Not Awarded
#  3          Not Awarded           NaN             Not Awarded
#  4          Not Awarded           NaN             Not Awarded
#  5          Not Awarded           NaN                    Pelé
#  6          Not Awarded           NaN          Flórián Albert
#  7          Not Awarded           NaN       Franz Beckenbauer
#  8          Not Awarded           NaN        Teófilo Cubillas
#  9          Not Awarded           NaN         Władysław Żmuda
#  10         Not Awarded           NaN         Antonio Cabrini
#  11         Not Awarded           NaN           Manuel Amoros
#  12         Not Awarded           NaN              Enzo Scifo
#  13         Not Awarded           NaN       Robert Prosinečki
#  14  Michel Preud'homme           2.0           Marc Overmars
#  15      Fabien Barthez           5.0            Michael Owen
#  16         Oliver Kahn           5.0          Landon Donovan
#  17    Gianluigi Buffon           5.0          Lukas Podolski
#  18       Iker Casillas           5.0           Thomas Müller
#  19        Manuel Neuer           4.0              Paul Pogba
#  20    Thibaut Courtois           3.0           Kylian Mbappé
#  21   Emiliano Martínez           3.0          Enzo Fernández
#
#     FIFA Fair Play Trophy
#  0            Not Awarded
#  1            Not Awarded
#  2            Not Awarded
#  3            Not Awarded
#  4            Not Awarded
#  5            Not Awarded
#  6            Not Awarded
#  7            Not Awarded
#  8                   Peru
#  9           West Germany
#  10             Argentina
#  11                Brazil
#  12                Brazil
#  13               England
#  14                Brazil
#  15       England  France
#  16               Belgium
#  17         Brazil  Spain
#  18                 Spain
#  19              Colombia
#  20                 Spain
#  21               England  ,
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteFIFA World Cup  \
#  0   Fédération internationale de football associat...
#  1                                         Tournaments
#  2                                       Qualification
#  3                                              Finals
#  4                                              Squads
#  5                                          Final draw
#  6                                        Broadcasters
#  7                                                Bids
#  8                                           Officials
#  9                                    Team appearances
#  10                                    Overall records
#  11                                      Miscellaneous
#  12  1 Argentina, Paraguay and Uruguay will host th...
#
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteFIFA World Cup.1
#  0   Fédération internationale de football associat...
#  1   Uruguay 1930 Italy 1934 France 1938 Brazil 195...
#  2   19302 1934 1938 1950 1954 1958 1962 1966 1970 ...
#  3   1930 1934 1938 19503 1954 1958 1962 1966 1970 ...
#  4   1930 1934 1938 1950 1954 1958 1962 1966 1970 1...
#  5                  1998 2002 2006 2010 2014 2018 2022
# ...
#  9                                                1962
#  10                                               1966
#  11                                               1970
#  12                                               1974
#  13                                               1978
#  14                                               1982
#  15                                               1986
#  16                                               1990
#  17                                               1994
#  18                                               1998
#  19                                               2002
#  20                                               2006
#  21                                               2010
#  22                                               2014
#  23                                               2018
#  24                                               2022
#  25                                               2026
#  26                                               2030
#  27                                               2034
#
#                                                      1
#  0   1986 Mexico Colombia‡ Canada United States 199...
#  1      Uruguay Hungary Italy Netherlands Spain Sweden
#  2                                        Italy Sweden
#  3                            France Argentina Germany
#  4                                      Brazil Germany
#  5                                                 NaN
#  6                                              Brazil
#  7                                         Switzerland
#  8                                              Sweden
#  9                        Chile Argentina West Germany
#  10                         England West Germany Spain
#  11                                   Mexico Argentina
#  12               West Germany Italy Netherlands Spain
#  13                     Argentina Mexico Iran Colombia
#  14                                 Spain West Germany
#  15              Mexico Colombia‡ Canada United States
#  16  Italy Austria England France Greece Soviet Uni...
#  17                       United States Brazil Morocco
#  18                         France Morocco Switzerland
#  19                           South Korea–Japan Mexico
#  20        Germany Brazil England Morocco South Africa
#  21   South Africa Egypt Libya–Tunisia Morocco Nigeria
#  22                                    Brazil Colombia
#  23  Russia Belgium–Netherlands England Portugal–Spain
#  24    Qatar Australia Japan South Korea United States
#  25                Canada–Mexico–United States Morocco
#  26  Morocco–Portugal–Spain Uruguay–Argentina–Chile...
#  27                                       Saudi Arabia  ,
#          0                                               1
#  0    1930  Uruguay Hungary Italy Netherlands Spain Sweden
#  1    1934                                    Italy Sweden
#  2    1938                        France Argentina Germany
#  3   1942†                                  Brazil Germany
#  4   1946†                                             NaN
#  5    1950                                          Brazil
#  6    1954                                     Switzerland
#  7    1958                                          Sweden
#  8    1962                    Chile Argentina West Germany
#  9    1966                      England West Germany Spain
#  10   1970                                Mexico Argentina
#  11   1974            West Germany Italy Netherlands Spain
#  12   1978                  Argentina Mexico Iran Colombia
#  13   1982                              Spain West Germany,
#         0                                                  1
#  0   1986              Mexico Colombia‡ Canada United States
#  1   1990  Italy Austria England France Greece Soviet Uni...
#  2   1994                       United States Brazil Morocco
#  3   1998                         France Morocco Switzerland
#  4   2002                           South Korea–Japan Mexico
#  5   2006        Germany Brazil England Morocco South Africa
#  6   2010   South Africa Egypt Libya–Tunisia Morocco Nigeria
#  7   2014                                    Brazil Colombia
#  8   2018  Russia Belgium–Netherlands England Portugal–Spain
#  9   2022    Qatar Australia Japan South Korea United States
#  10  2026                Canada–Mexico–United States Morocco
#  11  2030  Morocco–Portugal–Spain Uruguay–Argentina–Chile...
#  12  2034                                       Saudi Arabia,
#                                                vteFIFA  \
#  0   History of FIFA FIFA Anthem FIFA Congress FIFA...
#  1                                      Football codes
#  2                                      Confederations
#  3                                   Men's tournaments
#  4                                 Women's tournaments
#  5                                   Other tournaments
#  6                                          Presidents
#  7                                 Secretaries General
#  8                                              Awards
#  9                                            Rankings
#  10                                         Congresses
#  11                                         Corruption
#  12                                             Others
#  13                                  Category  Commons
#
#                                              vteFIFA.1  \
#  0   History of FIFA FIFA Anthem FIFA Congress FIFA...
#  1            Association football Beach soccer Futsal
#  2                  AFC CAF CONCACAF CONMEBOL OFC UEFA
#  3   FIFA World Cup FIFA U-20 World Cup FIFA U-17 W...
#  4   FIFA Women's World Cup FIFA U-20 Women's World...
#  5   FIFA Arab Cup FIFAe World Cup FIFAe Nations Se...
#  6   Robert Guérin (1904–1906) Daniel Burley Woolfa...
#  7   Louis Muhlinghaus (1904–1906) Wilhelm Hirschma...
#  8   FIFA 100 FIFA Ballon d'Or FIFA Champions Badge...
#  9   FIFA Men's World Ranking (Former systems: 1999...
#  10  51st (Paris 1998) 53rd (Seoul 2002) 61st (Züri...
#  11  "FIFA's Dirty Secrets" Garcia Report 2015 FIFA...
#  12  FIFA (video game series) FIFA Confederations C...
#  13                                  Category  Commons
#
#                                              vteFIFA.2
#  0   History of FIFA FIFA Anthem FIFA Congress FIFA...
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                  Category  Commons  ,
#           vteWorld association football championships  \
#  0  Football at the Summer Olympics Football at th...
#  1                                                Men
#  2                                           National
#  3                                               Club
#  4                                              Women
#  5                                           National
#  6                                               Club
#  7                                           Variants
#
#         vteWorld association football championships.1  \
#  0  Football at the Summer Olympics Football at th...
#  1  National FIFA World Cup FIFA U-20 World Cup FI...
#  2  FIFA World Cup FIFA U-20 World Cup FIFA U-17 W...
#  3  FIFA Club World Cup (Intercontinental Cup) FIF...
#  4  National FIFA Women's World Cup FIFA U-20 Wome...
#  5  FIFA Women's World Cup FIFA U-20 Women's World...
#  6  FIFA Women's Club World Cup (International Wom...
#  7  FIFA Futsal World Cup FIFA Futsal Women's Worl...
#
#         vteWorld association football championships.2
#  0  Football at the Summer Olympics Football at th...
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN  ,
#            0                                                  1
#  0  National  FIFA World Cup FIFA U-20 World Cup FIFA U-17 W...
#  1      Club  FIFA Club World Cup (Intercontinental Cup) FIF...,
#            0                                                  1
#  0  National  FIFA Women's World Cup FIFA U-20 Women's World...
#  1      Club  FIFA Women's Club World Cup (International Wom...,
#                 vteInternational association football  \
#  0  FIFA Federations Teams Competitions World Cup ...
#  1                                             Africa
#  2                                               Asia
#  3                                             Europe
#  4          North & Central America and the Caribbean
#  5                                            Oceania
#  6                                      South America
#  7                                           Non-FIFA
#  8                                              Games
#  9  See also Geography Codes Player/Club of the Ce...
#
#               vteInternational association football.1  \
#  0  FIFA Federations Teams Competitions World Cup ...
#  1  CAF – Africa Cup of Nations U-23 U-20 U-17 Afr...
#  2  AFC – Asian Cup U-23 U-20 U-17 Regional (ASEAN...
#  3  UEFA – Euro U-21 U-19 U-17 Nations League Inte...
#  4  CONCACAF – Gold Cup U-20 U-17 U-15 Nations League
#  5             OFC – Men's Nations Cup U-19 U-16/U-17
#  6  CONMEBOL – Copa América U-20 U-17 U-15 Interre...
#  7  CONIFA – CONIFA World Football Cup CONIFA Euro...
#  8  African Games Arab Games Asian Games Central A...
#  9  See also Geography Codes Player/Club of the Ce...
#
#               vteInternational association football.2
#  0  FIFA Federations Teams Competitions World Cup ...
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN
#  8                                                NaN
#  9  See also Geography Codes Player/Club of the Ce...  ,
#                vteNational association football teams  \
#  0  FIFA FIFA World Cup Summer Olympics Football A...
#  1                                                AFC
#  2                                                CAF
#  3                                           CONCACAF
#  4                                           CONMEBOL
#  5                                                OFC
#  6                                               UEFA
#  7                                            Defunct
#  8  Teams indicated in italics are associate/full ...
#
#              vteNational association football teams.1
#  0  FIFA FIFA World Cup Summer Olympics Football A...
#  1  Afghanistan Australia Bahrain Bangladesh Bhuta...
#  2  Algeria Angola Benin Botswana Burkina Faso Bur...
#  3  Anguilla Antigua and Barbuda Aruba Bahamas Bar...
#  4  Argentina Bolivia Brazil Chile Colombia Ecuado...
#  5  American Samoa Cook Islands Fiji Kiribati* New...
#  6  Albania Andorra Armenia Austria Azerbaijan Bel...
#  7  Czechoslovakia Saar West Germany East Germany ...
#  8  Teams indicated in italics are associate/full ...  ,
#                     vteWorld cups  \
#  0             List of world cups
#  1                           Team
#  2                     Individual
#  3                  Winter sports
#  4  See also: World championships
#
#                                       vteWorld cups.1
#  0                                 List of world cups
#  1  Association football men men's club women wome...
#  2  Archery Bowling Ten-pin bowling Nine-pin bowli...
#  3  Biathlon Curling Skiing Alpine Cross-country F...
#  4                      See also: World championships  ,
#                  vteWorld championships  \
#  0   List of world sports championships
#  1                       Olympic sports
#  2                                 Team
#  3                           Individual
#  4                         Discontinued
#  5                    Paralympic sports
#  6                                 Team
#  7                           Individual
#  8                        Combat sports
#  9                           Cue sports
#  10                         Mind sports
#  11                          Motorsport
#  12                         Auto racing
#  13                   Motorcycle sports
#  14                               Other
#  15                        Other sports
#  16                                Team
#  17                          Individual
#  18                             Esports
#  19                See also: World cups
#
#                               vteWorld championships.1
#  0                  List of world sports championships
#  1   Team Association football men men's club women...
#  2   Association football men men's club women wome...
#  3   Aquatic sports Archery Athletics outdoor race ...
#  4   Basque pelota Croquet singles team Karate Lacr...
#  5   Team Blind football Para Ice Hockey Men Women ...
#  6   Blind football Para Ice Hockey Men Women Wheel...
#  7   Archery Athletics Badminton Bobsleigh and skel...
#  8   Kendo Kickboxing (amateur) Muaythai Sambo Sumo...
#  9   Carom billiards Three-cushion men women team F...
#  10  Backgammon Bridge Chess open women team Draugh...
#  11  Auto racing Formula E Formula One Hill climb K...
#  12  Formula E Formula One Hill climb Karting Rally...
#  13  Endurance Enduro SuperEnduro Hard Enduro team ...
#  14  Aeroplane sport Aerobatic Aerobatic GP Powerbo...
#  15  Team American football men women Australian fo...
#  16  American football men women Australian footbal...
#  17  Air sports ballooning gliding parachuting para...
#  18  Call of Duty Counter-Strike Dota 2 eSailing FI...
#  19                               See also: World cups  ,
#                0                                                  1
#  0          Team  Association football men men's club women wome...
#  1    Individual  Aquatic sports Archery Athletics outdoor race ...
#  2  Discontinued  Basque pelota Croquet singles team Karate Lacr...,
#              0                                                  1
#  0        Team  Blind football Para Ice Hockey Men Women Wheel...
#  1  Individual  Archery Athletics Badminton Bobsleigh and skel...,
#                     0                                                  1
#  0        Auto racing  Formula E Formula One Hill climb Karting Rally...
#  1  Motorcycle sports  Endurance Enduro SuperEnduro Hard Enduro team ...
#  2              Other  Aeroplane sport Aerobatic Aerobatic GP Powerbo...,
#              0                                                  1
#  0        Team  American football men women Australian footbal...
#  1  Individual  Air sports ballooning gliding parachuting para...
#  2     Esports  Call of Duty Counter-Strike Dota 2 eSailing FI...,
#    Authority control databases  \
#  0               International
#  1                    National
#
#                         Authority control databases.1
#  0                                               VIAF
#  1  Norway Germany Israel United States Czech Repu...  ]

# %% [markdown]
# ## Pivot table
# - index, columns, values, aggfunc

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages (from openpyxl) (1.1.0)

# %%
df = pd.read_excel('../data/02. sales-funnel.xlsx')
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Account   17 non-null     int64
#  1   Name      17 non-null     object
#  2   Rep       17 non-null     object
#  3   Manager   17 non-null     object
#  4   Product   17 non-null     object
#  5   Quantity  17 non-null     int64
#  6   Price     17 non-null     int64
#  7   Status    17 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 1.2+ KB

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
# 16   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 0           CPU         1   30000  presented
# 1      Software         1   10000  presented
# 2   Maintenance         2    5000    pending
# 3           CPU         1   35000   declined
# 4           CPU         2   65000        won
# 5           CPU         2   40000    pending
# 6      Software         1   10000  presented
# 7   Maintenance         2    5000    pending
# 8           CPU         1   35000   declined
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %% [markdown]
# #### index 설정

# %%
df_name = df.groupby('Name').sum()
df_name
# Out:
#                               Account                                   Rep  \
# Name
# Barton LLC                     740150                            John Smith
# Fritsch, Russel and Anderson   737550                          Craig Booker
# Herman LLC                     141962                           Cedric Moss
# Jerde-Hilpert                  412290                            John Smith
# Kassulke, Ondricka and Metz    307599                            Wendy Yule
# Keeling LLC                    688981                            Wendy Yule
# Kiehn-Spinka                   146832                         Daniel Hilton
# Koepp Ltd                     1459666                  Wendy YuleWendy Yule
# Kulas Inc                      437790            Daniel HiltonDaniel Hilton
# Purdy-Kunde                    163416                           Cedric Moss
# Stokes LLC                     478688                Cedric MossCedric Moss
# Trantow-Barrows               2143398  Craig BookerCraig BookerCraig Booker
#
#                                                            Manager  \
# Name
# Barton LLC                                            Debra Henley
# Fritsch, Russel and Anderson                          Debra Henley
# Herman LLC                                           Fred Anderson
# Jerde-Hilpert                                         Debra Henley
# Kassulke, Ondricka and Metz                          Fred Anderson
# Keeling LLC                                          Fred Anderson
# Kiehn-Spinka                                          Debra Henley
# Koepp Ltd                               Fred AndersonFred Anderson
# Kulas Inc                                 Debra HenleyDebra Henley
# Purdy-Kunde                                          Fred Anderson
# Stokes LLC                              Fred AndersonFred Anderson
# Trantow-Barrows               Debra HenleyDebra HenleyDebra Henley
#
#                                              Product  Quantity   Price  \
# Name
# Barton LLC                                       CPU         1   35000
# Fritsch, Russel and Anderson                     CPU         1   35000
# Herman LLC                                       CPU         2   65000
# Jerde-Hilpert                            Maintenance         2    5000
# Kassulke, Ondricka and Metz              Maintenance         3    7000
# Keeling LLC                                      CPU         5  100000
# Kiehn-Spinka                                     CPU         2   65000
# Koepp Ltd                                 CPUMonitor         4   70000
# Kulas Inc                                CPUSoftware         3   50000
# Purdy-Kunde                                      CPU         1   30000
# Stokes LLC                       MaintenanceSoftware         2   15000
# Trantow-Barrows               CPUSoftwareMaintenance         4   45000
#
#                                                  Status
# Name
# Barton LLC                                     declined
# Fritsch, Russel and Anderson                   declined
# Herman LLC                                          won
# Jerde-Hilpert                                   pending
# Kassulke, Ondricka and Metz                         won
# Keeling LLC                                         won
# Kiehn-Spinka                                        won
# Koepp Ltd                             declinedpresented
# Kulas Inc                              pendingpresented
# Purdy-Kunde                                   presented
# Stokes LLC                             pendingpresented
# Trantow-Barrows               presentedpresentedpending

# %%
df.pivot_table(index=['Name'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'John Smith'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.pivot_table(index=['Name'])
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
#    8585         fill_value=fill_value,
#    8586         margins=margins,
#    8587         dropna=dropna,
#    8588         margins_name=margins_name,
#    8589         observed=observed,
#    8590         sort=sort,
#    8591     )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:167, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     164     values = list(values)
#     166 grouped = data.groupby(keys, observed=observed, sort=sort)
# --> 167 agged = grouped.agg(aggfunc)
#     169 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     170     agged = agged.dropna(how="all")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/internals/managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/internals/blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert John Smith to numeric

# %%
df.groupby(['Rep','Manager']).sum()
# Out:
#                              Account  \
# Rep           Manager
# Cedric Moss   Fred Anderson   784066
# Craig Booker  Debra Henley   2880948
# Daniel Hilton Debra Henley    584622
# John Smith    Debra Henley   1152440
# Wendy Yule    Fred Anderson  2456246
#
#                                                                           Name  \
# Rep           Manager
# Cedric Moss   Fred Anderson          Herman LLCPurdy-KundeStokes LLCStokes LLC
# Craig Booker  Debra Henley   Trantow-BarrowsTrantow-BarrowsTrantow-BarrowsF...
# Daniel Hilton Debra Henley                      Kiehn-SpinkaKulas IncKulas Inc
# John Smith    Debra Henley                             Jerde-HilpertBarton LLC
# Wendy Yule    Fred Anderson  Kassulke, Ondricka and MetzKeeling LLCKoepp Lt...
#
#                                                Product  Quantity   Price  \
# Rep           Manager
# Cedric Moss   Fred Anderson  CPUCPUMaintenanceSoftware         5  110000
# Craig Booker  Debra Henley   CPUSoftwareMaintenanceCPU         5   80000
# Daniel Hilton Debra Henley              CPUCPUSoftware         5  115000
# John Smith    Debra Henley              MaintenanceCPU         3   40000
# Wendy Yule    Fred Anderson   MaintenanceCPUCPUMonitor        12  177000
#
#                                                         Status
# Rep           Manager
# Cedric Moss   Fred Anderson       wonpresentedpendingpresented
# Craig Booker  Debra Henley   presentedpresentedpendingdeclined
# Daniel Hilton Debra Henley                 wonpendingpresented
# John Smith    Debra Henley                     pendingdeclined
# Wendy Yule    Fred Anderson            wonwondeclinedpresented

# %%
# 멀티 인덱스 설정
df.pivot_table(index = ['Rep', 'Manager'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'Herman LLCPurdy-KundeStokes LLCStokes LLC'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 # 멀티 인덱스 설정
# ----> 2 df.pivot_table(index = ['Rep', 'Manager'])
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
#    8585         fill_value=fill_value,
#    8586         margins=margins,
#    8587         dropna=dropna,
#    8588         margins_name=margins_name,
#    8589         observed=observed,
#    8590         sort=sort,
#    8591     )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:167, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     164     values = list(values)
#     166 grouped = data.groupby(keys, observed=observed, sort=sort)
# --> 167 agged = grouped.agg(aggfunc)
#     169 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     170     agged = agged.dropna(how="all")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/internals/managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/internals/blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert Herman LLCPurdy-KundeStokes LLCStokes LLC to numeric

# %% [markdown]
# #### values 설정

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df.pivot_table(index = ['Manager', 'Rep'], values = 'Price')
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
df.pivot_table(index = ['Manager', 'Rep'], values = 'Price', aggfunc = np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
df.pivot_table(index = ['Manager', 'Rep'], values = 'Price', aggfunc = [np.sum, len])
# Out:
#                                 sum   len
#                               Price Price
# Manager       Rep
# Debra Henley  Craig Booker    80000     4
#               Daniel Hilton  115000     3
#               John Smith      40000     2
# Fred Anderson Cedric Moss    110000     4
#               Wendy Yule     177000     4

# %% [markdown]
# #### columns 설정

# %%
df.pivot_table(index = ['Manager', 'Rep'], values = 'Price', columns = 'Product', aggfunc = np.sum)
# Out:
# Product                           CPU  Maintenance  Monitor  Software
# Manager       Rep
# Debra Henley  Craig Booker    65000.0       5000.0      NaN   10000.0
#               Daniel Hilton  105000.0          NaN      NaN   10000.0
#               John Smith      35000.0       5000.0      NaN       NaN
# Fred Anderson Cedric Moss     95000.0       5000.0      NaN   10000.0
#               Wendy Yule     165000.0       7000.0   5000.0       NaN

# %%
df.pivot_table(index = ['Manager', 'Rep'], 
               values = 'Price', 
               columns = 'Product', 
               aggfunc = np.sum, 
               fill_value = 0               # fill_value 는 NaN 값을 채워달라는 명령어
              )
# Out:
# Product                         CPU  Maintenance  Monitor  Software
# Manager       Rep
# Debra Henley  Craig Booker    65000         5000        0     10000
#               Daniel Hilton  105000            0        0     10000
#               John Smith      35000         5000        0         0
# Fred Anderson Cedric Moss     95000         5000        0     10000
#               Wendy Yule     165000         7000     5000         0

# %%
df.pivot_table(index = ['Manager', 'Rep', 'Product'], values = ['Price', 'Quantity'], aggfunc = np.sum, fill_value=0)
# Out:
#                                           Price  Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000         2
#                             Maintenance    5000         2
#                             Software      10000         1
#               Daniel Hilton CPU          105000         4
#                             Software      10000         1
#               John Smith    CPU           35000         1
#                             Maintenance    5000         2
# Fred Anderson Cedric Moss   CPU           95000         3
#                             Maintenance    5000         1
#                             Software      10000         1
#               Wendy Yule    CPU          165000         7
#                             Maintenance    7000         3
#                             Monitor        5000         2

# %%
df.pivot_table(index = ['Manager', 'Rep', 'Product'],
               values = ['Price', 'Quantity'], 
               aggfunc = [np.sum, np.mean], 
               fill_value = 0,
              margins = True)
# Out:
#                                             sum                   mean  \
#                                           Price Quantity         Price
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2  32500.000000
#                             Maintenance    5000        2   5000.000000
#                             Software      10000        1  10000.000000
#               Daniel Hilton CPU          105000        4  52500.000000
#                             Software      10000        1  10000.000000
#               John Smith    CPU           35000        1  35000.000000
#                             Maintenance    5000        2   5000.000000
# Fred Anderson Cedric Moss   CPU           95000        3  47500.000000
#                             Maintenance    5000        1   5000.000000
#                             Software      10000        1  10000.000000
#               Wendy Yule    CPU          165000        7  82500.000000
#                             Maintenance    7000        3   7000.000000
#                             Monitor        5000        2   5000.000000
# All                                      522000       30  30705.882353
#
#
#                                          Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU          1.000000
#                             Maintenance  2.000000
#                             Software     1.000000
#               Daniel Hilton CPU          2.000000
#                             Software     1.000000
#               John Smith    CPU          1.000000
#                             Maintenance  2.000000
# Fred Anderson Cedric Moss   CPU          1.500000
#                             Maintenance  1.000000
#                             Software     1.000000
#               Wendy Yule    CPU          3.500000
#                             Maintenance  3.000000
#                             Monitor      2.000000
# All                                      1.764706

# %% [markdown]
# #### pip 명령
# - python의 공식 모듈 관리자
# - pip list
# - pip install module_name
# - pip uninstall module_name

# %%
#!pip list

# %% [markdown]
# #### conda 명령
# - conda list
# - conda install module_name
# - conda uninstall module_name
# - conda install -c channel_name module_name

# %% [markdown]
# ## Google Maps API 설치

# %%
# AIzaSyCnTTJgg19JeTWrX3Yl4TH-6G99ONeBLkI

# %% [markdown]
# #### windows
# - conda install -c conda-forge googlemaps
#
# #### mac(m1)
# - pip install googlemaps

# %%
import googlemaps

# %%
gmaps_key = 'AIzaSyCnTTJgg19JeTWrX3Yl4TH-6G99ONeBLkI'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
gmaps.geocode('서울영등포경찰서', language ='ko')
# Out:
# [{'address_components': [{'long_name': '608',
#     'short_name': '608',
#     'types': ['premise']},
#    {'long_name': '국회대로',
#     'short_name': '국회대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-043',
#     'short_name': '150-043',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'geometry': {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5273930802915,
#      'lng': 126.9021580802915},
#     'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ1TimJLaffDURptXOs0Tj6sY',
#   'plus_code': {'compound_code': 'GWG2+C8 대한민국 서울특별시',
#    'global_code': '8Q98GWG2+C8'},
#   'types': ['establishment', 'point_of_interest', 'police']}]

# %% [markdown]
# ---

# %% [markdown]
# ## Python 반복문

# %%
# 간단한 for문 예제
for n in [1, 2, 3, 4]:
    print(n)
# Out:
# 1
# 2
# 3
# 4

# %%
# 조금 복잡한 for문 예제
for n in range(10):
    print(n**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## 위 코드를 한줄로 : list comprehension

# %%
[n**2 for n in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ## pandas에 잘 맞춰진 반복문용 명령 itterrows()
# - Pandas 데이터 프레임은 대부분 2차원
# - 이럴 때 for문을 사용하면, n번 지정한 것을 반복해서 하면 가독률이 떨어짐
# - Pandas 데이터 프레임으로 반복문을 만들떄 itterows() 옵션을 사용하면 편함
# - 받을때, 인덱스와 내용으로 나누어 받는 것만 주의
