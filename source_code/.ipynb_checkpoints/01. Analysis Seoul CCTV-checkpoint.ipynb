# %% [markdown]
# # Pandas에서 엑셀 및 텍스트 파일 읽기
# - python에서 R 만큼의 강력한 데이터 핸들링 성능을 제공하는 모듈
# - 단일 프로세스에서는 최대 효율
# - 코딩 가능하고 응용 가능한 엑셀로 받아들여도 됨
# - 누군가는 스테로이드를 맞은 엑셀로 표현함

# %% [markdown]
# ### import MODULE : MODULE을 사용하겠다
# - 사용 : MODULE.function
#
# ### import MODULE as md
# - 모듈을 사용할 건데, 앞으로는 md라는 이름으로 부르겠다
# - 사용 : md.function
#
# ### from MODULE import function
# - 모듈에 포함된 function 이라는 함수만 사용하겠다.
# - 사용 : function

# %%
# 원하는 모듈이 설치되어 있다면 import 명령을 통해 사용하겠다고 선언한다
import pandas as pd

# %% [markdown]
# - 통상 csv는 띄어쓰기로 구분되니 그냥 read_csv 명령으로 읽기만 해도 된다.
# - 긴 파일명을 끝까지 입력하지 말고 적당한 곳에서 TAB 키를 눌러보자
# - 한글은 encoding 설정이 필수

# %%
CCTV_Seoul = pd.read_csv('../data/01. Seoul_CCTV.csv', encoding = 'utf-8')
CCTV_Seoul.head() # head() : 앞부분 5개만 보고 싶어!
# Out:
#     순번   구분     총 계 2015년 이전 설치된 CCTV  2015년  2016년   2017년   2018년   2019년  \
# 0  NaN    계  99,515             8,759  5,725  8,537  10,770  10,619  12,855
# 1  1.0  종로구   2,031               549    158    128     143     142      67
# 2  2.0  중 구   2,718               275    236    239     372     386     155
# 3  3.0  용산구   3,258                88     38    295     491     147     335
# 4  4.0  성동구   4,409               190    352    278     939     457     640
#
#     2020년  2021년  2022년   2023년
# 0  11,525  9,358  9,379  11,988
# 1     237     82    225     300
# 2     364    419    137     135
# 3     473    486    500     405
# 4     483    366    233     471

# %% [markdown]
# ## 컬럼 이름 조회
# - 변수명.columns : column의 이름만 조회 하고 싶을 때 사용
# - 변수명.columns[i] : index 번호를 대괄호 안에 넣으면 해당 컬럼 이름만 조회 가능

# %%
CCTV_Seoul.columns
# Out:
# Index(['순번', '구분', '총 계', '2015년 이전 설치된 CCTV', '2015년', '2016년', '2017년',
#        '2018년', '2019년', '2020년', '2021년', '2022년', '2023년'],
#       dtype='object')

# %%
CCTV_Seoul.columns[0]
# Out:
# '순번'

# %% [markdown]
# ## 컬럼 이름 변경
# ### rename() 함수 사용
# - 변수명.rename(columns = {변수명.columns[인덱스번호]: '바꿀 껄럼명'}, inplace = True)
# - inplace = True를 해줘야 데이터가 업데이트 된다.

# %%
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[1] : '구별'}, inplace = True)
CCTV_Seoul.head()
# Out:
#     순번   구별     총 계 2015년 이전 설치된 CCTV  2015년  2016년   2017년   2018년   2019년  \
# 0  NaN    계  99,515             8,759  5,725  8,537  10,770  10,619  12,855
# 1  1.0  종로구   2,031               549    158    128     143     142      67
# 2  2.0  중 구   2,718               275    236    239     372     386     155
# 3  3.0  용산구   3,258                88     38    295     491     147     335
# 4  4.0  성동구   4,409               190    352    278     939     457     640
#
#     2020년  2021년  2022년   2023년
# 0  11,525  9,358  9,379  11,988
# 1     237     82    225     300
# 2     364    419    137     135
# 3     473    486    500     405
# 4     483    366    233     471

# %%
CCTV_Seoul = CCTV_Seoul.drop(['순번'], axis = 1)
CCTV_Seoul.head()
# Out:
#     구별     총 계 2015년 이전 설치된 CCTV  2015년  2016년   2017년   2018년   2019년  \
# 0    계  99,515             8,759  5,725  8,537  10,770  10,619  12,855
# 1  종로구   2,031               549    158    128     143     142      67
# 2  중 구   2,718               275    236    239     372     386     155
# 3  용산구   3,258                88     38    295     491     147     335
# 4  성동구   4,409               190    352    278     939     457     640
#
#     2020년  2021년  2022년   2023년
# 0  11,525  9,358  9,379  11,988
# 1     237     82    225     300
# 2     364    419    137     135
# 3     473    486    500     405
# 4     483    366    233     471

# %%
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[2] : '2015년 이전 설치'}, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별     총 계 2015년 이전 설치  2015년  2016년   2017년   2018년   2019년   2020년  \
# 0    계  99,515       8,759  5,725  8,537  10,770  10,619  12,855  11,525
# 1  종로구   2,031         549    158    128     143     142      67     237
# 2  중 구   2,718         275    236    239     372     386     155     364
# 3  용산구   3,258          88     38    295     491     147     335     473
# 4  성동구   4,409         190    352    278     939     457     640     483
#
#    2021년  2022년   2023년
# 0  9,358  9,379  11,988
# 1     82    225     300
# 2    419    137     135
# 3    486    500     405
# 4    366    233     471

# %% [markdown]
# # Excel 파일 읽기
# - 변수명 = pd.read_excel('파일경로')

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages (from openpyxl) (1.1.0)

# %%
pop_Seoul = pd.read_excel('../data/01. Seoul_Population.xlsx')
pop_Seoul.head()
# Out:
# /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    동별(1)  동별(2) 2023 3/4 2023 3/4.1 2023 3/4.2 2023 3/4.3 2023 3/4.4  \
# 0  동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1  동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2     합계     소계  4475726    9655918    4660459    4995459    9407540
# 3    NaN    종로구    72304     151127      72222      78905     139945
# 4    NaN     중구    64609     131825      63661      68164     121405
#
#   2023 3/4.5 2023 3/4.6 2023 3/4.7  ... 2023 4/4.2 2023 4/4.3 2023 4/4.4  \
# 0    한국인 (명)    한국인 (명)  등록외국인 (명)  ...      계 (명)      계 (명)    한국인 (명)
# 1         남자         여자         소계  ...         남자         여자         소계
# 2    4552501    4855039     248378  ...    4649446    4989353    9386034
# 3      67625      72320      11182  ...      71890      78563     139417
# 4      58788      62617      10420  ...      63495      68298     121312
#
#   2023 4/4.5 2023 4/4.6 2023 4/4.7 2023 4/4.8 2023 4/4.9 2023 4/4.10  \
# 0    한국인 (명)    한국인 (명)  등록외국인 (명)  등록외국인 (명)  등록외국인 (명)   세대당인구 (명)
# 1         남자         여자         소계         남자         여자          소계
# 2    4540031    4846003     252765     109415     143350         2.1
# 3      67306      72111      11036       4584       6452        1.93
# 4      58659      62653      10481       4836       5645        1.87
#
#     2023 4/4.11
# 0  65세이상고령자 (명)
# 1            소계
# 2       1743696
# 3         28764
# 4         25920
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Excel 파일 정제
# - 엑셀 설정
# - 자료를 읽기 시잘 행(header)를 지정
# - 읽어올 엑셀의 컬럼을 지정(usecols)

# %%
pop_Seoul = pd.read_excel('../data/01. Seoul_Population.xlsx',header = 2, usecols = 'B, D, G, J, N')
pop_Seoul.head()
# Out:
# /opt/anaconda3/envs/ds_study/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   동별(2)     소계.1     소계.2    소계.3     소계.5
# 0    소계  9655918  9407540  248378  1725801
# 1   종로구   151127   139945   11182    28610
# 2    중구   131825   121405   10420    25737
# 3   용산구   230692   216152   14540    39972
# 4   성동구   285543   278366    7177    48988

# %% [markdown]
# # 컬럼의 이름 바꾸기

# %%
pop_Seoul.rename(columns = {
    pop_Seoul.columns[0]: '구별',
    pop_Seoul.columns[1]: '인구수',
    pop_Seoul.columns[2]: '한국인',
    pop_Seoul.columns[3]: '외국인',
    pop_Seoul.columns[4]: '고령자',
    }, inplace = True)
pop_Seoul.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   소계  9655918  9407540  248378  1725801
# 1  종로구   151127   139945   11182    28610
# 2   중구   131825   121405   10420    25737
# 3  용산구   230692   216152   14540    39972
# 4  성동구   285543   278366    7177    48988

# %% [markdown]
# ## CCTV 데이터 훑어보기

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   구별           26 non-null     object
#  1   총 계          26 non-null     object
#  2   2015년 이전 설치  26 non-null     object
#  3   2015년        26 non-null     object
#  4   2016년        26 non-null     object
#  5   2017년        26 non-null     object
#  6   2018년        26 non-null     object
#  7   2019년        26 non-null     object
#  8   2020년        26 non-null     object
#  9   2021년        26 non-null     object
#  10  2022년        26 non-null     object
#  11  2023년        26 non-null     object
# dtypes: object(12)
# memory usage: 2.6+ KB

# %%
CCTV_Seoul.loc[:, '총 계':'2023년'] = CCTV_Seoul.loc[:, '총 계':'2023년'].applymap(lambda x: int(x.replace(',', '')))
CCTV_Seoul.head()
# Out:
#     구별    총 계 2015년 이전 설치 2015년 2016년  2017년  2018년  2019년  2020년 2021년 2022년  \
# 0    계  99515        8759  5725  8537  10770  10619  12855  11525  9358  9379
# 1  종로구   2031         549   158   128    143    142     67    237    82   225
# 2  중 구   2718         275   236   239    372    386    155    364   419   137
# 3  용산구   3258          88    38   295    491    147    335    473   486   500
# 4  성동구   4409         190   352   278    939    457    640    483   366   233
#
#    2023년
# 0  11988
# 1    300
# 2    135
# 3    405
# 4    471

# %%
CCTV_Seoul.head()
# Out:
#     구별    총 계 2015년 이전 설치 2015년 2016년  2017년  2018년  2019년  2020년 2021년 2022년  \
# 0    계  99515        8759  5725  8537  10770  10619  12855  11525  9358  9379
# 1  종로구   2031         549   158   128    143    142     67    237    82   225
# 2  중 구   2718         275   236   239    372    386    155    364   419   137
# 3  용산구   3258          88    38   295    491    147    335    473   486   500
# 4  성동구   4409         190   352   278    939    457    640    483   366   233
#
#    2023년
# 0  11988
# 1    300
# 2    135
# 3    405
# 4    471

# %%
CCTV_Seoul.tail()
# Out:
#      구별   총 계 2015년 이전 설치 2015년 2016년 2017년 2018년 2019년 2020년 2021년 2022년  \
# 21  관악구  5772         774   447   607   675   663   889   404   549   135
# 22  서초구  5395         227   552   514  1022   422   339   419   565   878
# 23  강남구  7721         672   814  1280   981   735   787   913   505   588
# 24  송파구  4031         223   183   126   227   526  1050   237   151   431
# 25  강동구  3549         571   154   202   273   377   356   614   262   381
#
#    2023년
# 21   629
# 22   457
# 23   446
# 24   877
# 25   359

# %%
CCTV_Seoul.sort_values(by = '총 계', ascending=True).head()
# Out:
#      구별   총 계 2015년 이전 설치 2015년 2016년 2017년 2018년 2019년 2020년 2021년 2022년  \
# 1   종로구  2031         549   158   128   143   142    67   237    82   225
# 10  도봉구  2378           3     0    68    80   152   149   156   552   557
# 2   중 구  2718         275   236   239   372   386   155   364   419   137
# 11  노원구  3006         156   466   310   162   208   311   382   213   161
# 20  동작구  3024         534   124   245   270   299   312   433    28   372
#
#    2023년
# 1    300
# 10   661
# 2    135
# 11   637
# 20   407

# %%
CCTV_Seoul.sort_values(by = '총 계', ascending=False).head()
# Out:
#      구별    총 계 2015년 이전 설치 2015년 2016년  2017년  2018년  2019년  2020년 2021년  \
# 0     계  99515        8759  5725  8537  10770  10619  12855  11525  9358
# 23  강남구   7721         672   814  1280    981    735    787    913   505
# 21  관악구   5772         774   447   607    675    663    889    404   549
# 22  서초구   5395         227   552   514   1022    422    339    419   565
# 12  은평구   5027         524   317   493    361    579    979    386   520
#
#    2022년  2023년
# 0   9379  11988
# 23   588    446
# 21   135    629
# 22   878    457
# 12   481    387

# %%
print(CCTV_Seoul['2015년 이전 설치'].unique())
# Out:
# [8759 549 275 88 190 309 8 334 281 37 3 156 524 1126 111 4 303 406 0 1054
#  534 774 227 672 223 571]

# %%
CCTV_Seoul = CCTV_Seoul[CCTV_Seoul['2015년 이전 설치'] != 0]
CCTV_Seoul['최근증가율'] = (
    (CCTV_Seoul['2015년'] + CCTV_Seoul['2016년'] + CCTV_Seoul['2017년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2019년']
    + CCTV_Seoul['2020년'] + CCTV_Seoul['2021년'] + CCTV_Seoul['2022년'] + CCTV_Seoul['2023년']) / CCTV_Seoul['2015년 이전 설치'] * 100
)

# %%
CCTV_Seoul.sort_values(by = '최근증가율', ascending = False)
# Out:
#       구별    총 계 2015년 이전 설치 2015년 2016년  2017년  2018년  2019년  2020년 2021년  \
# 15   양천구   4447           4   216   418    566    827    321    352   347
# 10   도봉구   2378           3     0    68     80    152    149    156   552
# 6   동대문구   3268           8    70   749    670    199    215    229   226
# 9    강북구   3331          37    68   210      4    375    963    569   298
# 3    용산구   3258          88    38   295    491    147    335    473   486
# 14   마포구   3155         111   146   446    368    368    494    298   177
# 22   서초구   5395         227   552   514   1022    422    339    419   565
# 4    성동구   4409         190   352   278    939    457    640    483   366
# 11   노원구   3006         156   466   310    162    208    311    382   213
# 24   송파구   4031         223   183   126    227    526   1050    237   151
# 8    성북구   4578         281   294   572    448    850    713    226   418
# 7    중랑구   4512         334   145   153    170    215   1074    976   507
# 5    광진구   3828         309    95    42    666    460    712    191   740
# 17   구로구   5003         406   248   340    543    531    781    652   685
# 16   강서구   3546         303   192   167    416    259    457    362   441
# 23   강남구   7721         672   814  1280    981    735    787    913   505
# 0      계  99515        8759  5725  8537  10770  10619  12855  11525  9358
# 2    중 구   2718         275   236   239    372    386    155    364   419
# 12   은평구   5027         524   317   493    361    579    979    386   520
# 21   관악구   5772         774   447   607    675    663    889    404   549
# 25   강동구   3549         571   154   202    273    377    356    614   262
# 20   동작구   3024         534   124   245    270    299    312    433    28
# 19  영등포구   4566        1054   209   248    311    657     65   1214   283
# 1    종로구   2031         549   158   128    143    142     67    237    82
# 13  서대문구   3793        1126   109   277    416    246    325    441   331
#
#    2022년  2023년         최근증가율
# 15   386   1010      111075.0
# 10   557    661  79166.666667
# 6    317    585       40750.0
# 9    797     10   8902.702703
# 3    500    405   3602.272727
# 14   124    623   2742.342342
# 22   878    457   2276.651982
# 4    233    471   2220.526316
# 11   161    637   1826.923077
# 24   431    877   1707.623318
# 8    355    421   1529.181495
# 7    294    644   1250.898204
# 5    273    340   1138.834951
# 17   339    478    1132.26601
# 16   596    353    1070.29703
# 23   588    446   1048.958333
# 0   9379  11988   1036.145679
# 2    137    135    888.363636
# 12   481    387    859.351145
# 21   135    629    645.736434
# 25   381    359    521.541156
# 20   372    407    466.292135
# 19   341    184    333.206831
# 1    225    300    269.945355
# 13   174    348    236.856128

# %%
CCTV_Seoul = CCTV_Seoul.drop([0])

# %%
CCTV_Seoul
# Out:
#       구별   총 계 2015년 이전 설치 2015년 2016년 2017년 2018년 2019년 2020년 2021년 2022년  \
# 1    종로구  2031         549   158   128   143   142    67   237    82   225
# 2    중 구  2718         275   236   239   372   386   155   364   419   137
# 3    용산구  3258          88    38   295   491   147   335   473   486   500
# 4    성동구  4409         190   352   278   939   457   640   483   366   233
# 5    광진구  3828         309    95    42   666   460   712   191   740   273
# 6   동대문구  3268           8    70   749   670   199   215   229   226   317
# 7    중랑구  4512         334   145   153   170   215  1074   976   507   294
# 8    성북구  4578         281   294   572   448   850   713   226   418   355
# 9    강북구  3331          37    68   210     4   375   963   569   298   797
# 10   도봉구  2378           3     0    68    80   152   149   156   552   557
# 11   노원구  3006         156   466   310   162   208   311   382   213   161
# 12   은평구  5027         524   317   493   361   579   979   386   520   481
# 13  서대문구  3793        1126   109   277   416   246   325   441   331   174
# 14   마포구  3155         111   146   446   368   368   494   298   177   124
# 15   양천구  4447           4   216   418   566   827   321   352   347   386
# 16   강서구  3546         303   192   167   416   259   457   362   441   596
# 17   구로구  5003         406   248   340   543   531   781   652   685   339
# 19  영등포구  4566        1054   209   248   311   657    65  1214   283   341
# 20   동작구  3024         534   124   245   270   299   312   433    28   372
# 21   관악구  5772         774   447   607   675   663   889   404   549   135
# 22   서초구  5395         227   552   514  1022   422   339   419   565   878
# 23   강남구  7721         672   814  1280   981   735   787   913   505   588
# 24   송파구  4031         223   183   126   227   526  1050   237   151   431
# 25   강동구  3549         571   154   202   273   377   356   614   262   381
#
#    2023년         최근증가율
# 1    300    269.945355
# 2    135    888.363636
# 3    405   3602.272727
# 4    471   2220.526316
# 5    340   1138.834951
# 6    585       40750.0
# 7    644   1250.898204
# 8    421   1529.181495
# 9     10   8902.702703
# 10   661  79166.666667
# 11   637   1826.923077
# 12   387    859.351145
# 13   348    236.856128
# 14   623   2742.342342
# 15  1010      111075.0
# 16   353    1070.29703
# 17   478    1132.26601
# 19   184    333.206831
# 20   407    466.292135
# 21   629    645.736434
# 22   457   2276.651982
# 23   446   1048.958333
# 24   877   1707.623318
# 25   359    521.541156

# %% [markdown]
# ## 인구 현황 데이터 훑어보기

# %%
pop_Seoul.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   소계  9655918  9407540  248378  1725801
# 1  종로구   151127   139945   11182    28610
# 2   중구   131825   121405   10420    25737
# 3  용산구   230692   216152   14540    39972
# 4  성동구   285543   278366    7177    48988

# %%
pop_Seoul.tail()
# Out:
#      구별     인구수     한국인    외국인     고령자
# 21  관악구  500582  485172  15410   84664
# 22  서초구  410766  406404   4362   64761
# 23  강남구  546291  540957   5334   85288
# 24  송파구  661515  655744   5771  107605
# 25  강동구  462453  458385   4068   81739

# %%
pop_Seoul = pop_Seoul.drop([0])

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인     고령자
# 1    종로구  151127  139945  11182   28610
# 2     중구  131825  121405  10420   25737
# 3    용산구  230692  216152  14540   39972
# 4    성동구  285543  278366   7177   48988
# 5    광진구  351959  336604  15355   56173
# 6   동대문구  359113  341238  17875   66440
# 7    중랑구  387940  382797   5143   77949
# 8    성북구  440089  427671  12418   79739
# 9    강북구  294804  290155   4649   68119
# 10   도봉구  310133  307740   2393   69508
# 11   노원구  504423  499989   4434   95384
# 12   은평구  471155  467098   4057   92820
# 13  서대문구  321379  307441  13938   57632
# 14   마포구  375639  364257  11382   57462
# 15   양천구  440591  437401   3190   75420
# 16   강서구  569978  564339   5639  100929
# 17   구로구  416815  393929  22886   79150
# 18   금천구  242076  228611  13465   44793
# 19  영등포구  398290  375586  22704   66975
# 20   동작구  390740  380154  10586   69944
# 21   관악구  500582  485172  15410   84664
# 22   서초구  410766  406404   4362   64761
# 23   강남구  546291  540957   5334   85288
# 24   송파구  661515  655744   5771  107605
# 25   강동구  462453  458385   4068   81739

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
len(pop_Seoul['구별'].unique())
# Out:
# 25

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  151127  139945  11182  28610  7.399075  18.931098
# 2   중구  131825  121405  10420  25737  7.904419  19.523611
# 3  용산구  230692  216152  14540  39972  6.302776  17.326999
# 4  성동구  285543  278366   7177  48988  2.513457  17.156085
# 5  광진구  351959  336604  15355  56173  4.362724  15.960098

# %%
pop_Seoul.sort_values(by = '인구수', ascending=False).head()
# Out:
#      구별     인구수     한국인    외국인     고령자     외국인비율      고령자비율
# 24  송파구  661515  655744   5771  107605  0.872391  16.266449
# 16  강서구  569978  564339   5639  100929  0.989336  17.707526
# 23  강남구  546291  540957   5334   85288  0.976403  15.612192
# 11  노원구  504423  499989   4434   95384  0.879024  18.909526
# 21  관악구  500582  485172  15410   84664  3.078417  16.913113

# %%
pop_Seoul.sort_values(by = '외국인', ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 17   구로구  416815  393929  22886  79150  5.490685  18.989240
# 19  영등포구  398290  375586  22704  66975  5.700369  16.815637
# 6   동대문구  359113  341238  17875  66440  4.977542  18.501140
# 21   관악구  500582  485172  15410  84664  3.078417  16.913113
# 5    광진구  351959  336604  15355  56173  4.362724  15.960098

# %%
pop_Seoul.sort_values(by = '외국인비율', ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 2     중구  131825  121405  10420  25737  7.904419  19.523611
# 1    종로구  151127  139945  11182  28610  7.399075  18.931098
# 3    용산구  230692  216152  14540  39972  6.302776  17.326999
# 19  영등포구  398290  375586  22704  66975  5.700369  16.815637
# 18   금천구  242076  228611  13465  44793  5.562303  18.503693

# %%
pop_Seoul.sort_values(by = '고령자비율', ascending=False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9   강북구  294804  290155   4649  68119  1.576980  23.106539
# 10  도봉구  310133  307740   2393  69508  0.771604  22.412320
# 7   중랑구  387940  382797   5143  77949  1.325720  20.093056
# 12  은평구  471155  467098   4057  92820  0.861075  19.700523
# 2    중구  131825  121405  10420  25737  7.904419  19.523611

# %%
pop_Seoul.sort_values(by = '고령자', ascending=False).head()
# Out:
#      구별     인구수     한국인   외국인     고령자     외국인비율      고령자비율
# 24  송파구  661515  655744  5771  107605  0.872391  16.266449
# 16  강서구  569978  564339  5639  100929  0.989336  17.707526
# 11  노원구  504423  499989  4434   95384  0.879024  18.909526
# 12  은평구  471155  467098  4057   92820  0.861075  19.700523
# 23  강남구  546291  540957  5334   85288  0.976403  15.612192

# %%
CCTV_Seoul.head()
# Out:
#     구별   총 계 2015년 이전 설치 2015년 2016년 2017년 2018년 2019년 2020년 2021년 2022년  \
# 1  종로구  2031         549   158   128   143   142    67   237    82   225
# 2  중 구  2718         275   236   239   372   386   155   364   419   137
# 3  용산구  3258          88    38   295   491   147   335   473   486   500
# 4  성동구  4409         190   352   278   939   457   640   483   366   233
# 5  광진구  3828         309    95    42   666   460   712   191   740   273
#
#   2023년        최근증가율
# 1   300   269.945355
# 2   135   888.363636
# 3   405  3602.272727
# 4   471  2220.526316
# 5   340  1138.834951

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  151127  139945  11182  28610  7.399075  18.931098
# 2   중구  131825  121405  10420  25737  7.904419  19.523611
# 3  용산구  230692  216152  14540  39972  6.302776  17.326999
# 4  성동구  285543  278366   7177  48988  2.513457  17.156085
# 5  광진구  351959  336604  15355  56173  4.362724  15.960098

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_result.head()
# Out:
#      구별   총 계 2015년 이전 설치 2015년 2016년 2017년 2018년 2019년 2020년 2021년 2022년  \
# 0   종로구  2031         549   158   128   143   142    67   237    82   225
# 1   용산구  3258          88    38   295   491   147   335   473   486   500
# 2   성동구  4409         190   352   278   939   457   640   483   366   233
# 3   광진구  3828         309    95    42   666   460   712   191   740   273
# 4  동대문구  3268           8    70   749   670   199   215   229   226   317
#
#   2023년        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0   300   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 1   405  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 2   471  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 3   340  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 4   585      40750.0  359113  341238  17875  66440  4.977542  18.501140

# %% [markdown]
# #### 년도별 데이터 컬럼 삭제
# - del
# - drop()

# %%
del data_result['2015년 이전 설치']
del data_result['2015년']
del data_result['2016년']
del data_result['2017년']
del data_result['2018년']
del data_result['2019년']
del data_result['2020년']
del data_result['2021년']
del data_result['2022년']
del data_result['2023년']

# %%
data_result
# Out:
#       구별   총 계         최근증가율     인구수     한국인    외국인     고령자     외국인비율  \
# 0    종로구  2031    269.945355  151127  139945  11182   28610  7.399075
# 1    용산구  3258   3602.272727  230692  216152  14540   39972  6.302776
# 2    성동구  4409   2220.526316  285543  278366   7177   48988  2.513457
# 3    광진구  3828   1138.834951  351959  336604  15355   56173  4.362724
# 4   동대문구  3268       40750.0  359113  341238  17875   66440  4.977542
# 5    중랑구  4512   1250.898204  387940  382797   5143   77949  1.325720
# 6    성북구  4578   1529.181495  440089  427671  12418   79739  2.821702
# 7    강북구  3331   8902.702703  294804  290155   4649   68119  1.576980
# 8    도봉구  2378  79166.666667  310133  307740   2393   69508  0.771604
# 9    노원구  3006   1826.923077  504423  499989   4434   95384  0.879024
# 10   은평구  5027    859.351145  471155  467098   4057   92820  0.861075
# 11  서대문구  3793    236.856128  321379  307441  13938   57632  4.336936
# 12   마포구  3155   2742.342342  375639  364257  11382   57462  3.030037
# 13   양천구  4447      111075.0  440591  437401   3190   75420  0.724027
# 14   강서구  3546    1070.29703  569978  564339   5639  100929  0.989336
# 15   구로구  5003    1132.26601  416815  393929  22886   79150  5.490685
# 16  영등포구  4566    333.206831  398290  375586  22704   66975  5.700369
# 17   동작구  3024    466.292135  390740  380154  10586   69944  2.709218
# 18   관악구  5772    645.736434  500582  485172  15410   84664  3.078417
# 19   서초구  5395   2276.651982  410766  406404   4362   64761  1.061918
# 20   강남구  7721   1048.958333  546291  540957   5334   85288  0.976403
# 21   송파구  4031   1707.623318  661515  655744   5771  107605  0.872391
# 22   강동구  3549    521.541156  462453  458385   4068   81739  0.879657
#
#         고령자비율
# 0   18.931098
# 1   17.326999
# 2   17.156085
# 3   15.960098
# 4   18.501140
# 5   20.093056
# 6   18.118835
# 7   23.106539
# 8   22.412320
# 9   18.909526
# 10  19.700523
# 11  17.932721
# 12  15.297134
# 13  17.117917
# 14  17.707526
# 15  18.989240
# 16  16.815637
# 17  17.900394
# 18  16.913113
# 19  15.765911
# 20  15.612192
# 21  16.266449
# 22  17.675093

# %% [markdown]
# #### 인덱스 변경
# - set_index()
# - 선택한 컬럼을 데이터 프레임의 인덱스로 지점

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140

# %% [markdown]
# #### 상관계수
# - corr()
# - correlation의 약자
# - 상관계수가 0.2 이상인 데이터를 비교

# %%
data_result.corr()
# Out:
#             총 계     최근증가율       인구수       한국인       외국인       고령자     외국인비율  \
# 총 계    1.000000 -0.169807  0.493638  0.485146  0.026830  0.364826 -0.255292
# 최근증가율 -0.169807  1.000000 -0.085321 -0.069704 -0.268176 -0.010394 -0.235980
# 인구수    0.493638 -0.085321  1.000000  0.998641 -0.240739  0.933127 -0.619338
# 한국인    0.485146 -0.069704  0.998641  1.000000 -0.290990  0.937305 -0.655439
# 외국인    0.026830 -0.268176 -0.240739 -0.290990  1.000000 -0.326082  0.837181
# 고령자    0.364826 -0.010394  0.933127  0.937305 -0.326082  1.000000 -0.692384
# 외국인비율 -0.255292 -0.235980 -0.619338 -0.655439  0.837181 -0.692384  1.000000
# 고령자비율 -0.405694  0.242748 -0.330175 -0.312631 -0.238929  0.020787 -0.115881
#
#           고령자비율
# 총 계   -0.405694
# 최근증가율  0.242748
# 인구수   -0.330175
# 한국인   -0.312631
# 외국인   -0.238929
# 고령자    0.020787
# 외국인비율 -0.115881
# 고령자비율  1.000000

# %%
data_result['CCTV비율'] = data_result['총 계'] / data_result['인구수'] * 100

# %%
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140
#
#         CCTV비율
# 구별
# 종로구   1.343903
# 용산구   1.412273
# 성동구   1.544076
# 광진구   1.087627
# 동대문구   0.91002

# %%
data_result.sort_values(by = 'CCTV비율', ascending=False).head()
# Out:
#       총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 성동구  4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 강남구  7721  1048.958333  546291  540957   5334  85288  0.976403  15.612192
# 용산구  3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 종로구  2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 서초구  5395  2276.651982  410766  406404   4362  64761  1.061918  15.765911
#
#        CCTV비율
# 구별
# 성동구  1.544076
# 강남구  1.413349
# 용산구  1.412273
# 종로구  1.343903
# 서초구    1.3134

# %%
data_result.sort_values(by = 'CCTV비율').head()
# Out:
#       총 계         최근증가율     인구수     한국인   외국인     고령자     외국인비율      고령자비율  \
# 구별
# 노원구  3006   1826.923077  504423  499989  4434   95384  0.879024  18.909526
# 송파구  4031   1707.623318  661515  655744  5771  107605  0.872391  16.266449
# 강서구  3546    1070.29703  569978  564339  5639  100929  0.989336  17.707526
# 도봉구  2378  79166.666667  310133  307740  2393   69508  0.771604  22.412320
# 강동구  3549    521.541156  462453  458385  4068   81739  0.879657  17.675093
#
#        CCTV비율
# 구별
# 노원구  0.595928
# 송파구  0.609359
# 강서구  0.622129
# 도봉구  0.766768
# 강동구  0.767429

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
plt.rcParams['axes.unicode_minus'] = False
rc('font', family = 'Arial Unicode MS')
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140
#
#         CCTV비율
# 구별
# 종로구   1.343903
# 용산구   1.412273
# 성동구   1.544076
# 광진구   1.087627
# 동대문구   0.91002

# %% [markdown]
# #### 소계 컬럼 시각화

# %%
data_result['총 계'].plot(kind = 'barh', grid = True, figsize = (10, 10));

# %%
def drawGraph():
    data_result['총 계'].sort_values().plot(
        kind = 'barh', grid = True, title = '가장 CCTV가 많은 구', figsize = (10, 10));

drawGraph()

# %%
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140
#
#         CCTV비율
# 구별
# 종로구   1.343903
# 용산구   1.412273
# 성동구   1.544076
# 광진구   1.087627
# 동대문구   0.91002

# %%
    data_result['CCTV비율'].sort_values().plot(
        kind = 'barh', grid = True, title = '가장 CCTV 비율이 높은 구', figsize = (10, 10));

# %% [markdown]
# ## 데이터의 경향 표시

# %%
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140
#
#         CCTV비율
# 구별
# 종로구   1.343903
# 용산구   1.412273
# 성동구   1.544076
# 광진구   1.087627
# 동대문구   0.91002

# %% [markdown]
# #### 인구수와 총계 컬럼으로 scatter plot 그리기

# %%
def drawGraph():

    plt.figure(figsize = (14, 10))
    plt.scatter(data_result['인구수'],data_result['총 계'], s = 50)
    plt.xlabel = '인구수'
    plt.ylabel = 'CCTV'
    plt.grid(True)
    plt.show()

drawGraph()

# %% [markdown]
# #### numpy를 이용한 1차 직선 만들기
# - np.polyfit() : 직선을 구성하기 위한 계수를 계산
# - np.poly1d() : oplyfit으로 찾은 계수로 파이썬에서 사용할 수 있는 함수로 만들어주는 기능

# %%
import numpy as np

# %%
# Convert 'population' and 'total' to NumPy arrays
population = np.array(data_result['인구수'], dtype=float)
total = np.array(data_result['총 계'], dtype=float)

# Perform linear regression
coefficients = np.linalg.lstsq(np.vstack([population, np.ones_like(population)]).T, total, rcond=None)[0]
slope, intercept = coefficients

coefficients
# Out:
# array([5.33107226e-03, 1.91934333e+03])

# %%
f1 = np.poly1d(coefficients)
f1
# Out:
# poly1d([5.33107226e-03, 1.91934333e+03])

# %%
f1(400000)
# Out:
# 4051.772236803914

# %% [markdown]
# - 인구가 40만인 구에서 서울시의 전체 경향에 맞는 적당한 CCTV 수는?

# %%
fx = np.linspace(100000, 700000, 100)

# %% [markdown]
# - 경향선을 그리기 위한 x 데이터 생성
# - np.linspace(a, b, n): a부터 b까지 n개의 등간격 데이터 생성

# %%
def drawGraph():

    plt.figure(figsize = (14, 10))
    plt.scatter(data_result['인구수'],data_result['총 계'], s = 50)
    plt.plot(fx, f1(fx), ls = 'dashed', lw = 3, color = 'g')
    plt.xlabel = '인구수'
    plt.ylabel = 'CCTV'
    plt.grid(True)
    plt.show()

drawGraph()

# %% [markdown]
# ## 강조하고 싶은 데이터를 시각화

# %% [markdown]
# ### 그래프 다듬기
# #### 경향과 오차 만들기ㅣ
# - 경향(trend)과의 오차를 만들자
# - 경향은 f1 함수에 해당 인구를 입력
# - f1(data_result('인구수'))

# %%
data_result['오차'] = data_result['총 계'] - f1(data_result['인구수'])

# %%
data_result.head()
# Out:
#        총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031   269.945355  151127  139945  11182  28610  7.399075  18.931098
# 용산구   3258  3602.272727  230692  216152  14540  39972  6.302776  17.326999
# 성동구   4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 광진구   3828  1138.834951  351959  336604  15355  56173  4.362724  15.960098
# 동대문구  3268      40750.0  359113  341238  17875  66440  4.977542  18.501140
#
#         CCTV비율          오차
# 구별
# 종로구   1.343903  -694.01229
# 용산구   1.412273  108.820945
# 성동구   1.544076  967.406301
# 광진구   1.087627   32.337806
# 동대문구   0.91002 -565.800685

# %%
df_sort_f = data_result.sort_values(by = '오차', ascending= False)
df_sort_t = data_result.sort_values(by = '오차', ascending= True)

# %%
df_sort_f.head()
# Out:
#       총 계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강남구  7721  1048.958333  546291  540957   5334  85288  0.976403  15.612192
# 서초구  5395  2276.651982  410766  406404   4362  64761  1.061918  15.765911
# 관악구  5772   645.736434  500582  485172  15410  84664  3.078417  16.913113
# 성동구  4409  2220.526316  285543  278366   7177  48988  2.513457  17.156085
# 구로구  5003   1132.26601  416815  393929  22886  79150  5.490685  18.989240
#
#        CCTV비율           오차
# 구별
# 강남구  1.413349  2889.339871
# 서초구    1.3134  1285.833439
# 관악구  1.153058  1184.017853
# 성동구  1.544076   967.406301
# 구로구  1.200293   861.585783

# %%
df_sort_t.head()
# Out:
#       총 계         최근증가율     인구수     한국인    외국인     고령자     외국인비율      고령자비율  \
# 구별
# 노원구  3006   1826.923077  504423  499989   4434   95384  0.879024  18.909526
# 송파구  4031   1707.623318  661515  655744   5771  107605  0.872391  16.266449
# 강서구  3546    1070.29703  569978  564339   5639  100929  0.989336  17.707526
# 도봉구  2378  79166.666667  310133  307740   2393   69508  0.771604  22.412320
# 동작구  3024    466.292135  390740  380154  10586   69944  2.709218  17.900394
#
#        CCTV비율           오차
# 구별
# 노원구  0.595928 -1602.458795
# 송파구  0.609359 -1414.927599
# 강서구  0.622129 -1411.937237
# 도봉구  0.766768 -1194.684766
# 동작구  0.773916  -978.406508

# %%
from matplotlib.colors import ListedColormap
# colormap 을 사용자 정의로 커스텀 세팅
color_step = ['#e74c3c', '#2ecc71', '#95a9a6', '#2ecc71', '#3498db', '#3498db']
my_cmap = ListedColormap(color_step)

# %%
data_result
# Out:
#        총 계         최근증가율     인구수     한국인    외국인     고령자     외국인비율      고령자비율  \
# 구별
# 종로구   2031    269.945355  151127  139945  11182   28610  7.399075  18.931098
# 용산구   3258   3602.272727  230692  216152  14540   39972  6.302776  17.326999
# 성동구   4409   2220.526316  285543  278366   7177   48988  2.513457  17.156085
# 광진구   3828   1138.834951  351959  336604  15355   56173  4.362724  15.960098
# 동대문구  3268       40750.0  359113  341238  17875   66440  4.977542  18.501140
# 중랑구   4512   1250.898204  387940  382797   5143   77949  1.325720  20.093056
# 성북구   4578   1529.181495  440089  427671  12418   79739  2.821702  18.118835
# 강북구   3331   8902.702703  294804  290155   4649   68119  1.576980  23.106539
# 도봉구   2378  79166.666667  310133  307740   2393   69508  0.771604  22.412320
# 노원구   3006   1826.923077  504423  499989   4434   95384  0.879024  18.909526
# 은평구   5027    859.351145  471155  467098   4057   92820  0.861075  19.700523
# 서대문구  3793    236.856128  321379  307441  13938   57632  4.336936  17.932721
# 마포구   3155   2742.342342  375639  364257  11382   57462  3.030037  15.297134
# 양천구   4447      111075.0  440591  437401   3190   75420  0.724027  17.117917
# 강서구   3546    1070.29703  569978  564339   5639  100929  0.989336  17.707526
# 구로구   5003    1132.26601  416815  393929  22886   79150  5.490685  18.989240
# 영등포구  4566    333.206831  398290  375586  22704   66975  5.700369  16.815637
# 동작구   3024    466.292135  390740  380154  10586   69944  2.709218  17.900394
# 관악구   5772    645.736434  500582  485172  15410   84664  3.078417  16.913113
# 서초구   5395   2276.651982  410766  406404   4362   64761  1.061918  15.765911
# 강남구   7721   1048.958333  546291  540957   5334   85288  0.976403  15.612192
# 송파구   4031   1707.623318  661515  655744   5771  107605  0.872391  16.266449
# 강동구   3549    521.541156  462453  458385   4068   81739  0.879657  17.675093
#
#         CCTV비율           오차
# 구별
# 종로구   1.343903   -694.01229
# 용산구   1.412273   108.820945
# 성동구   1.544076   967.406301
# 광진구   1.087627    32.337806
# 동대문구   0.91002  -565.800685
# 중랑구   1.163066   524.520495
# 성북구   1.040244   312.510407
# 강북구   1.129903  -159.964759
# 도봉구   0.766768 -1194.684766
# 노원구   0.595928 -1602.458795
# 은평구   1.066952   595.895317
# 서대문구  1.180226   160.361995
# 마포구   0.839902  -766.901985
# 양천구   1.009326   178.834209
# 강서구   0.622129 -1411.937237
# 구로구   1.200293   861.585783
# 영등포구  1.146401   523.343897
# 동작구   0.773916  -978.406508
# 관악구   1.153058  1184.017853
# 서초구     1.3134  1285.833439
# 강남구   1.413349  2889.339871
# 송파구   0.609359 -1414.927599
# 강동구   0.767429  -835.713693

# %%
def drawGraph():

    plt.figure(figsize = (14, 10))
    plt.scatter(data_result['인구수'],data_result['총 계'], s = 50, c = data_result['오차'], cmap = my_cmap)
    plt.plot(fx, f1(fx), ls = 'dashed', lw = 3, color = 'g')
    for n in range(5):
        plt.text(
            df_sort_f['인구수'][n] * 1.02,
            df_sort_f['총 계'][n] * 0.98,
            df_sort_f.index[n],
            fontsize = 15
        )
    for n in range(5):
        plt.text(
            df_sort_t['인구수'][n] * 1.02,
            df_sort_t['총 계'][n] * 0.98,
            df_sort_t.index[n],
            fontsize = 15
        )
    plt.xlabel = '인구수'
    plt.ylabel = 'CCTV'
    plt.colorbar()
    plt.grid(True)
    plt.show()

drawGraph()

# %%
data_result.to_csv('../data/01. CCTV_result.csv', sep = ',', encoding = 'utf-8')
