# %%
import pandas as pd

# %%
df = pd.read_csv('../data/AICC_Project_wanted_joblist_merge.csv')
df
# Out:
#      Unnamed: 0    Company                                  Title  \
# 0             0  엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)
# 1             1        웨이커                   AI NLP 엔지니어(LLM 최적화)
# 2             2      셀렉트스타                             AI NLP 연구원
# 3             3         덴컴                          Front-end 개발자
# 4             4      테스트웍스                           NLP/LLM 엔지니어
# ..          ...        ...                                    ...
# 212         212        엘리스                                AI 엔지니어
# 213         213   딥브레인에이아이                       [400억↑투자] 산업기능요원
# 214         214        클럼엘            신입 Software Engineer (Data)
# 215         215     아하앤컴퍼니                            아하팀 AI 엔지니어
# 216         216       아이트럭                          ML 머신러닝 신입~초급
#
#                                                     스킬  \
# 0                                Pytorch,Python,OpenCV
# 1       Git,JIRA,Redis,Python,NLP,AWS,Spring Framework
# ...

# %%
del df['Unnamed: 0']

# %%
df.head(1)
# Out:
#      Company                                  Title            InfoDetails  \
# 0  엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)  Pytorch,Python,OpenCV
#
#               Address                                                Tag  \
# 0  강남구 강남대로162길 41-18  자유로운휴가,유망산업,커피·스낵바,건강검진지원,장비지원,식대지원,유연근무,육아휴직,...
#
#   D_Day                                               채용상세 Location   Career  \
# 0  상시채용  포지션 상세\n• 엔쓰리엔에서 AI Service를 위한 Vision 개발자를 모십...   서울 강남구  경력 1-5년
#
#                                   URL
# 0  https://www.wanted.co.kr/wd/221071

# %%
	Company	Title	스킬	위치상세	태그	마감일	채용상세

# %%
df.rename(columns={
    df.columns[2] : 'Skill',
    df.columns[3] : 'Address',
    df.columns[4] : 'Tag',
    df.columns[5] : 'D_Day',
    df.columns[6] : 'InfoDetails'},
    inplace= True)

# %%
df.head(2)
# Out:
#      Company                                  Title  \
# 0  엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)
# 1        웨이커                   AI NLP 엔지니어(LLM 최적화)
#
#                                             Skill  \
# 0                           Pytorch,Python,OpenCV
# 1  Git,JIRA,Redis,Python,NLP,AWS,Spring Framework
#
#                              Address  \
# 0                 강남구 강남대로162길 41-18
# 1  서울특별시 강남구 선릉로 667 11층 waiker, Inc
#
#                                                  Tag       D_Day  \
# 0  자유로운휴가,유망산업,커피·스낵바,건강검진지원,장비지원,식대지원,유연근무,육아휴직,...        상시채용
# 1              유망산업,자기계발지원,건강검진지원,유연근무,커피·스낵바,설립4~9년  2024.07.31
#
#                                          InfoDetails Location   Career  \
# 0  포지션 상세\n• 엔쓰리엔에서 AI Service를 위한 Vision 개발자를 모십...   서울 강남구  경력 1-5년
# 1  포지션 상세\n증시 데이터 환경을 기술로 개선하고 있는 웨이커입니다.\n\n웨이커는...   서울 강남구  경력 3-9년
#
#                                   URL
# 0  https://www.wanted.co.kr/wd/221071
# 1  https://www.wanted.co.kr/wd/215269

# %%
df = df.loc[:, ['Location', 'Company', 'Title', 'Career', 'Skill', 'Address', 'URL', 'InfoDetails', 'Tag', 'D_Day']]
df.head(2)
# Out:
#   Location    Company                                  Title   Career  \
# 0   서울 강남구  엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)  경력 1-5년
# 1   서울 강남구        웨이커                   AI NLP 엔지니어(LLM 최적화)  경력 3-9년
#
#                                             Skill  \
# 0                           Pytorch,Python,OpenCV
# 1  Git,JIRA,Redis,Python,NLP,AWS,Spring Framework
#
#                              Address                                 URL  \
# 0                 강남구 강남대로162길 41-18  https://www.wanted.co.kr/wd/221071
# 1  서울특별시 강남구 선릉로 667 11층 waiker, Inc  https://www.wanted.co.kr/wd/215269
#
#                                          InfoDetails  \
# 0  포지션 상세\n• 엔쓰리엔에서 AI Service를 위한 Vision 개발자를 모십...
# 1  포지션 상세\n증시 데이터 환경을 기술로 개선하고 있는 웨이커입니다.\n\n웨이커는...
#
#                                                  Tag       D_Day
# 0  자유로운휴가,유망산업,커피·스낵바,건강검진지원,장비지원,식대지원,유연근무,육아휴직,...        상시채용
# 1              유망산업,자기계발지원,건강검진지원,유연근무,커피·스낵바,설립4~9년  2024.07.31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     217 non-null    object
#  1   Company      217 non-null    object
#  2   Title        217 non-null    object
#  3   Career       217 non-null    object
#  4   Skill        167 non-null    object
#  5   Address      217 non-null    object
#  6   URL          217 non-null    object
#  7   InfoDetails  217 non-null    object
#  8   Tag          215 non-null    object
#  9   D_Day        217 non-null    object
# dtypes: object(10)
# memory usage: 17.1+ KB

# %%
df.to_csv('../data/AICC_Project_wanted_raw.csv', sep = ',', encoding = 'utf-8')

# %%
a = df['Location'][0].split()
a[1]
# Out:
# '강남구'

# %%
gu_list = []
for i in df['Location']:
    gu_raw = i.split()
    gu = gu_raw[1]
    gu_list.append(gu)

len(gu_list)
# Out:
# 217

# %%
df['Location'] = gu_list

# %%
df.head()
# Out:
#   Location    Company                                  Title    Career  \
# 0      강남구  엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)   경력 1-5년
# 1      강남구        웨이커                   AI NLP 엔지니어(LLM 최적화)   경력 3-9년
# 2      강남구      셀렉트스타                             AI NLP 연구원   경력 3-5년
# 3      강남구         덴컴                          Front-end 개발자  경력 4-10년
# 4      송파구      테스트웍스                           NLP/LLM 엔지니어  경력 3-10년
#
#                                                Skill  \
# 0                              Pytorch,Python,OpenCV
# 1     Git,JIRA,Redis,Python,NLP,AWS,Spring Framework
# 2  Git,MySQL,Pytorch,Tensorflow,Python,Spring Fra...
# 3  Git,GraphQL,React,JavaScript,Kotlin,Node.js,Py...
# 4         React,TypeScript,JPA,jQuery UI,Spring Boot
#
#                               Address                                 URL  \
# 0                  강남구 강남대로162길 41-18  https://www.wanted.co.kr/wd/221071
# ...

# %%
df.set_index('Location')
# Out:
#             Company                                  Title     Career  \
# Location
# 강남구       엔쓰리엔(N3N)  Deep Learning Engineer (Vision 연구/개발)    경력 1-5년
# 강남구             웨이커                   AI NLP 엔지니어(LLM 최적화)    경력 3-9년
# 강남구           셀렉트스타                             AI NLP 연구원    경력 3-5년
# 강남구              덴컴                          Front-end 개발자   경력 4-10년
# 송파구           테스트웍스                           NLP/LLM 엔지니어   경력 3-10년
# ...             ...                                    ...        ...
# 강남구             엘리스                                AI 엔지니어  신입-경력 10년
# 강남구        딥브레인에이아이                       [400억↑투자] 산업기능요원         신입
# 강남구             클럼엘            신입 Software Engineer (Data)         신입
# 강남구          아하앤컴퍼니                            아하팀 AI 엔지니어    경력 1-5년
# 서초구            아이트럭                          ML 머신러닝 신입~초급    경력 1-3년
#
#                                                       Skill  \
# Location
# ...
