# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ## Part(1) - Day06  :

# %% [markdown]
# ]

# %% [markdown]
# ## Today's mission
#
# - 웹 데이터 수집 및  Beautiful Soup 리뷰
#   - 웹 데이터 수집 개념
#   - 웹 데이터 기본 구조
#   - 웹 데이터 HTML
#   - Python 파이썬 관련 라이브러리 : Beautiful Soup
#
# - 실습 (1) google news 검색
#
# - 실습 (2) google news 검색 함수 작성

# %% [markdown]
# ]

# %% [markdown]
# ### 웹 데이터 수집 개념 :
#  - 크롤링(crawling) 과 스크래핑(Scraping)
#  - 웹 크롤러는 웹 페이지를 Chrome, IE 와 같은 브라우저로 접속하지 않고, Python 파이썬같은 프로그래밍 언어로 접속하여, 필요한 내용만 가져옴

# %% [markdown]
# ![%EC%BA%A1%EC%B2%981.JPG](attachment:%EC%BA%A1%EC%B2%981.JPG)

# %% [markdown]
# ### 웹 데이터 기본 구조 :
#  - CSS + HTML + Java

# %% [markdown]
# ![%EC%BA%A1%EC%B2%982.JPG](attachment:%EC%BA%A1%EC%B2%982.JPG)

# %% [markdown]
# ### 웹 데이터 HTML :
#  - HTML코드는 웹페이지를 제공하는 사람(웹사이트 운영자)과 이를 이용하는 사람(ex: 검색엔진, 브라우저)간의 규약
#  - 규약은 규약일 뿐, 너무 복잡하게 생각할 필요는 없음

# %% [markdown]
# ##### 주요 HTML 태그
#
# - h3 - 제목 (header)
# - p - 단락 (paragraph)
# - span - 개행 안 하는 단락
# - div - 구역(divison)
# - dl - 설명 리스트 (description list)
# - dt - 설명 헤더 (description header)
# - dd - 설명 내용
# - img - 이미지(image)
# - a - 링크(anchor)

# %% [markdown]
# ### Python 파이썬 관련 라이브러리 : Beautiful Soup
#  - 1) 뷰티플숩은 Crawling, Scraping 등을 위해 설계된 파이썬 패키지/라이브러리
#
#  --  (스크린 스크래핑의 대표적인 예로서, 웹 화면에서 데이터를 가져오는 웹 크롤링이라 이해하면 됨)

# %% [markdown]
# ##### 주요 특징
#
# - 1) HTML 구문 분석, 트리 탐색, 검색 및 수정을 위한 간단한 방법과 파이썬 기능을 활용하여 데이터 수집 프로그램 작성이 쉬움
# - 2) 대부분의 문서 Encoding 자동 변환 (Unicode <-> UTF-8)
# --   ex) unicode (세계문자 표준 기준코드, 16bit), UTF-8 (3bytes/1자), euc-kr (한글 2bytes/1자)
# - 3) lxml, html5lib 등 기능적 라이브러리를 사용하면, 속도 및 호환성 높은 응용프로그램 제작이 가능
#
# ##### 참고 site :
# - https://www.crummy.com/software/BeautifulSoup/
# - https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ### 실습 (1) google news 검색
#  - 참고사항 : robots.txt
#    https://searchadvisor.naver.com/guide/seo-basic-robots
#
# - 구글에서 검색 후 뉴스선택 (http://www.google.com/)

# %%
# 패키지 import
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### google news 검색 참고:
#
# https://news.google.com/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako
#
#  -> "https://news.google.com" + "/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako" (검색어: 코로나)

# %%
# HTML 파일 읽어들이기
base_url = "https://news.google.com"

# %%
search_url = "/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako"
url = base_url + search_url

# %%
url
# Out:
# 'https://news.google.com/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako'

# %%
# 검색정보 url GET 방식으로 요청
response = requests.get(url)
response                     # 200 : 응답코드 200 은 서버의 응답이 정상,   404 : url 이 잘못되거나 오류
# Out:
# <Response [200]>

# %%
# HTML parser 이용해 soup 객체 생성
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ko"><head><base href="https://news.google.com/"/><link href="//www.gstatic.com" ref="preconnect"/><meta content="origin" name="referrer"/><link href="https://news.google.com/search" rel="canonical"/><meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/><meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="뉴스" name="application-name"/><meta content="뉴스" name="apple-mobile-web-app-title"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="white" name="theme-color"/><meta content="no" name="msapplication-tap-highlight"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/><link href="//www.gstatic.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//lh3.googleusercontent.com" rel="preconnect"/><link href="//lh4.googleusercontent.com" rel="preconnect"/><link href="//lh5.googleusercontent.com" rel="preconnect"/><link href="//lh6.googleusercontent.com" rel="preconnect"/><link href="//ssl.gstatic.com" rel="preconnect"/><link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Google+Sans+Text:400,500,700,400i,500i,700i" rel="stylesheet"/><link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/><link href="/?lfhs=2" rel="home"/><link href="/?lfhs=2" rel="msapplication-starturl"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/><link href="//ssl.gstatic.com ...
# a.l=function(e){function g(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=e;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,c){if(!c||"none"==c.style.display)return!1;var f=b.defaultView;if(f&&f.getComputedStyle&&(f=f.getComputedStyle(c),"0px"==f.height||"0px"==f.width||"hidden"==f.visibility))return!1;if(!c.getBoundingClientRect)return!0;
# var h=c.getBoundingClientRect();c=h.left+a.pageXOffset;f=h.top+a.pageYOffset;if(0>f+h.height||0>c+h.width||0>=h.height||0>=h.width)return!1;b=b.documentElement;return f<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;"IMG"!=b.tagName||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=a.aft_counter.indexOf(b),-1!==b&&(b=1===a.aft_counter.splice(b,
# 1).length,0===a.aft_counter.length&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('A35Fe')</script><script nonce="lsVcNpukXBCWP_XuCK6YlQ">var _F_cssRowKey = 'boq-dots.DotsSplashUi_desktop_ms.0LVtqcO1oIw.L.W.O';var _F_combinedSignature = 'ALs0n2MKUqmBkvOy6E7aXES_YwCfDA3tAQ';function _DumpException(e) {throw e;}</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.0LVtqcO1oIw.L.W.O/am=CEAgAIPuAgNgBA/d=1/ed=1/rs=ALs0n2OPFQmgHPfRNjVXQ-WfrXGWSC6j7Q/m=search,_b,_tp" nonce="i-E0ipfJ06SbztK3cII8eg">html,body{height:100%;overflow:hidden}body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:rgba(0,0,0,.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd::placeholder{color:rgba(232,234,237,.38)}}@media all{body.dm7YTc .Y5O54e .VfPpkd-fmcmS-yrriRe.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:rgba(232,234,237,.38)}}@media screen and (forced-colors:active),(-ms-high-contrast:active){body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-fpDzbe-fmcmS,body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-L8ivfd-fmcmS{color:GrayText}body.dm7YTc .Y5O54e .VfPpkd-StrnGf-rymPhb .VfPpkd-StrnGf-rymPhb-ibnC6b-OWXEXe-OWB6Me .VfPpkd-StrnGf-rymPhb-b9t22c{opacity:1}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-webkit-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-moz-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::-ms-input-placeholder,body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd::placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcmS-yrriRe:not(.VfPpkd-fmcmS-yrriRe-OWXEXe-OWB6Me) .VfPpkd-fmcmS-wGMbrd:-ms-input-placeholder{color:#bdc1c6;color:var(--gm-outlinedtextfield-placeholder-color,#bdc1c6)}}@media all{body.dm7YTc .NGdKgb .VfPpkd-fmcm ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var n=this||self;/*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# function q(b,a){if(null===a)return!1;if("contains"in b&&1===a.nodeType)return b.contains(a);if("compareDocumentPosition"in b)return b===a||!!(b.compareDocumentPosition(a)&16);for(;a&&b!==a;)a=a.parentNode;return a===b};function r(b){return"mouseenter"===b?"mouseover":"mouseleave"===b?"mouseout":"pointerenter"===b?"pointerover":"pointerleave"===b?"pointerout":b}function t(b){b=b.target;!b.getAttribute&&b.parentNode&&(b=b.parentNode);return b}
# var u="undefined"!==typeof navigator&&/Macintosh/.test(navigator.userAgent),x="undefined"!==typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),y={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},z={Enter:13," ":32},A={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},B={CHECKBOX:!0,FILE:!0,OPTION:!0,
# RADIO:!0},C={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},D={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,INPUT:!0,LINK:!0,MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};function G(b){var a=b.event;var c=a.which||a.keyCode;!c&&a.key&&(c=z[a.key]);x&&3===c&&(c=13);if(13!==c&&32!==c)c=!1;else{var d=t(a);(a="keydown"!==a.type||!!(!("getAttribute"in d)||(d.getAttribute("type")||d.tagName).toUpperCase()in C||"BUTTON"===d.tagName.toUpperCase()||d.type&&"FILE"===d.type.toUpperCase()||d.isContentEditable)||a.ctrlKey||a.shiftKey||a.altKey||a.metaKey||(d.getAttribute("type")||d.tagName).toUpperCase()in B&&32===c)||((a=d.tagName in y)||(a=d.getAttributeNode("tabindex"),a=null!=
# a&&a.specified),a=!(a&&!d.disabled));if(a)c=!1;else{a=(d.getAttribute("role")||d.type||d.tagName).toUpperCase();var e=!(a in A)&&13===c;d="INPUT"!==d.tagName.toUpperCase()||!!d.type;c=(0===A[a]%c||e)&&d}}c&&(b.eiack=!0,b.eventType="click")}
# function H(b){var a;if(a=b.eiack){a=b.event;var c=t(a);c=(c.type||c.tagName).toUpperCase();if(!(a=32===(a.which||a.keyCode)&&"CHECKBOX"!==c)){a=t(b.event);c=a.tagName.toUpperCase();var d=(a.getAttribute("role")||"").toUpperCase();a="BUTTON"===c||"BUTTON"===d?!0:!(a.tagName.toUpperCase()in D)||"A"===c||"SELECT"===c||(a.getAttribute("type")||a.tagName).toUpperCase()in B||(a.getAttribute("type")||a.tagName).toUpperCase()in C?!1:!0}}a&&(b=b.event,b.preventDefault?b.preventDefault():b.returnValue=!1)}
# function I(b,a,c){a.eia||"click"!==a.eventType||a.eiack||void 0===c.clickonly||(a.eventType="clickonly",a.eia=[c.clickonly,b])};var J={};var K={},L=/\s*;\s*/;function M(b){this.l={};this.m={};this.g=null;this.i=[];this.o=b;this.B=G;this.v=H;this.u=I}M.prototype.handleEvent=function(b,a,c){N(this,{eventType:b,event:a,targetElement:a.target,eic:c,timeStamp:Date.now(),eia:void 0,eirp:void 0,eiack:void 0})};
# function N(b,a){if(!b.g){a.eirp=!0;var c;null==(c=b.i)||c.push(a)}if(c="click"===a.eventType)c=a.event,c=u&&c.metaKey||!u&&c.ctrlKey||2===c.which||null==c.which&&4===c.button||c.shiftKey;c?a.eventType="clickmod":b.B(a);for(c=a.targetElement;c&&c!==a.eic;){var d=b,e=c,g=a;var f=e.__jsaction;if(!f){var k;f=null;"getAttribute"in e&&(f=e.getAttribute("jsaction"));if(k=f){f=J[k];if(!f){f={};for(var E=k.split(L),v=0;v<E.length;v++){var p=E[v];if(p){var w=p.indexOf(":"),F=-1!==w;f[F?O(p.substr(0,w)):"click"]=
# F?O(p.substr(w+1)):p}}J[k]=f}e.__jsaction=f}else f=K,e.__jsaction=f}k=f[g.eventType];void 0!==k&&(g.eia=[k,e]);d.u(e,g,f);if(a.eia)break;c.__owner?c=c.__owner:(d=void 0,"#document-fragment"!==(null==(d=c.parentNode)?void 0:d.nodeName)?c=c.parentNode:(e=d=void 0,c=null!=(e=null==(d=c.parentNode)?void 0:d.host)?e:null))}if(c=a.eia)if(b.v(a),"mouseenter"===a.eventType||"mouseleave"===a.eventType||"pointerenter"===a.eventType||"pointerleave"===a.eventType)if(d=a.event,e=a.eventType,g=c[1],f=d.relatedTarget,
# !("mouseover"===d.type&&"mouseenter"===e||"mouseout"===d.type&&"mouseleave"===e||"pointerover"===d.type&&"pointerenter"===e||"pointerout"===d.type&&"pointerleave"===e)||f&&(f===g||q(g,f)))a.eia=void 0;else{d=a.event;e=c[1];g={};for(var h in d)"srcElement"!==h&&"target"!==h&&(f=h,k=d[f],"function"!==typeof k&&(g[f]=k));g.type="mouseover"===d.type?"mouseenter":"mouseout"===d.type?"mouseleave":"pointerover"===d.type?"pointerenter":"pointerleave";g.target=g.srcElement=e;g.bubbles=!1;a.event=g;a.targetElement=
# c[1]}b.g&&(h={eventType:a.eventType,event:a.event,targetElement:a.targetElement,eic:a.eic,eia:a.eia,timeStamp:a.timeStamp,eirp:a.eirp,eiack:a.eiack},"clickonly"===h.eventType&&(h.eventType="click"),b.g(h,!0),h=a.eia)&&("A"!==h[1].tagName||"click"!==a.eventType&&"clickmod"!==a.eventType||(h=a.event,h.preventDefault?h.preventDefault():h.returnValue=!1),b.g(a))}
# function P(b,a,c){if(!(a in b.l)&&b.o){var d=function(g,f,k){b.handleEvent(g,f,k)};b.l[a]=d;c=r(c||a);if(c!==a){var e=b.m[c]||[];e.push(a);b.m[c]=e}b.o.addEventListener(c,function(g){return function(f){d(a,f,g)}});"click"===a&&P(b,"keydown")}}M.prototype.j=function(b){return this.l[b]};M.prototype.ecrd=function(b){this.g=b;var a;if(null==(a=this.i)?0:a.length){for(b=0;b<this.i.length;b++)N(this,this.i[b]);this.i=null}};
# function O(b){return"function"===typeof String.prototype.trim?b.trim():b.replace(/^\s+/,"").replace(/\s+$/,"")};var Q="undefined"!==typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent);function R(b){this.g=b;this.i=[]}R.prototype.addEventListener=function(b,a){Q&&(this.g.style.cursor="pointer");var c=this.i,d=c.push,e=this.g;a=a(this.g);var g=!1;if("focus"===b||"blur"===b||"error"===b||"load"===b||"toggle"===b)g=!0;e.addEventListener(b,a,g);d.call(c,{eventType:b,j:a,capture:g})};var m="click dblclick focus focusin blur error focusout keydown keyup keypress load mouseover mouseout mouseenter mouseleave submit toggle touchstart touchend touchmove touchcancel auxclick change compositionstart compositionupdate compositionend beforeinput input select textinput copy cut paste mousedown mouseup wheel contextmenu dragover dragenter dragleave drop dragstart dragend pointerdown pointermove pointerup pointercancel pointerenter pointerleave pointerover pointerout gotpointercapture lostpointercapture ended loadedmetadata pagehide pageshow visibilitychange beforematch".split(" ");
# if(!(m instanceof Array)){var S;var T="undefined"!=typeof Symbol&&Symbol.iterator&&m[Symbol.iterator];if(T)S=T.call(m);else if("number"==typeof m.length)S={next:l()};else throw Error(String(m)+" is not an iterable or ArrayLike");for(var U,V=[];!(U=S.next()).done;)V.push(U.value)};var W=function(b){return{trigger:function(a){var c=b.j(a.type);c||(P(b,a.type),c=b.j(a.type));var d=a.target||a.srcElement;c&&c(a.type,a,d.ownerDocument.documentElement)},configure:function(a){a(b)}}}(function(){var b=window,a=new R(b.document.documentElement),c=new M(a);m.forEach(function(g){return P(c,g)});var d,e;"onwebkitanimationend"in b&&(d="webkitAnimationEnd");P(c,"animationend",d);"onwebkittransitionend"in b&&(e="webkitTransitionEnd");P(c,"transitionend",e);return{s:c,C:a}}().s),X=["BOQ_wizbind"],
# Y=window||n;X[0]in Y||"undefined"==typeof Y.execScript||Y.execScript("var "+X[0]);for(var Z;X.length&&(Z=X.shift());)X.length||void 0===W?Y[Z]&&Y[Z]!==Object.prototype[Z]?Y=Y[Z]:Y=Y[Z]={}:Y[Z]=W;}).call(this);
# </script><script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi_desktop_ms.ko.12U3S1apPNM.es5.O/am=CEAgAIPuAgNgBA/d=1/excm=_b,_tp,search/ed=1/dg=0/wt=2/ujg=1/rs=ALs0n2NvrFAaLvTRyEkShX7nTUZ2sO8xdg/m=_b,_tp" id="base-js" nocollect="" nonce="lsVcNpukXBCWP_XuCK6YlQ">"use strict";this.default_DotsSplashUi_desktop_ms=this.default_DotsSplashUi_desktop_ms||{};(function(_){var window=this;
# try{
# _._F_toggles_initialize=function(a){("undefined"!==typeof globalThis?globalThis:"undefined"!==typeof self?self:this)._F_toggles=a||[]};(0,_._F_toggles_initialize)([0x204008, 0xc0bba0c, 0x4600, ]);
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2024 Google, Inc
#  SPDX-License-Identifier: MIT
# */
# var baa,caa,La,gaa,Ua,Wa,haa,iaa,ib,lb,oaa,yb,Db,Ub,vaa,Zb,$b,ac,ec,yaa,gc,Baa,Faa,Gaa,wc,Tc,Laa,Maa,Kaa,Oaa,Raa,Qaa,Saa,Taa,Uaa,Xaa,Yaa,$aa,aba,rd,qd,sd,gd,fba,Md,iba,mba,nba,qba,je,ne,vba,xba,yba,zba,Bba,Cba,Gba,Iba,Jba,Mba,Uba,Qba,Yba,cf,$ba,aca,cca,tf,ica,jca,zf,Af,kca,lca,mca,nca,Ff,oca,pca,qca,rca,sca,uca,vca,zca,aaa,Aca,jg,Bca,pg,Cca,rg,tg,Dca,wg,xg,yg,Jca,Kca,Eg,Jg,Lca,Mca;_.aa=function(a){return function(){return aaa[a].apply(this,arguments)}};_.ba=function(a,b){return aaa[a]=b};
# _.da=function(a){_.ca.setTimeout(function(){throw a;},0)};_.ea=function(a){a&&"function"==typeof a.dispose&&a.dispose()};baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ha(d)?baa.apply(null,d):_.ea(d)}};_.ia=function(a,b){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ia);else{var c=Error().stack;c&&(this.stack=c)}a&&(this.message=String(a));void 0!==b&&(this.cause=b);this.o=!0};_.ka=function(a){return a[a.length-1]};
# _.la=function(a,b,c){for(var d="string"===typeof a?a.split(""):a,e=a.length-1;0<=e;--e)e in d&&b.call(c,d[e],e,a)};_.na=function(a,b,c){b=_.ma(a,b,c);return 0>b?null:"string"===typeof a?a.charAt(b):a[b]};_.ma=function(a,b,c){for(var d=a.length,e="string"===typeof a?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.pa=function(a,b){for(var c="string"===typeof a?a.split(""):a,d=a.length-1;0<=d;d--)if(d in c&&b.call(void 0,c[d],d,a))return d;return-1};
# _.sa=function(a,b){return 0<=(0,_.ra)(a,b)};_.ua=function(a,b){_.sa(a,b)||a.push(b)};_.wa=function(a,b){b=(0,_.ra)(a,b);var c;(c=0<=b)&&_.va(a,b);return c};_.va=function(a,b){return 1==Array.prototype.splice.call(a,b,1).length};_.xa=function(a){return Array.prototype.concat.apply([],arguments)};_.ya=function(a){var b=a.length;if(0<b){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};
# _.za=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ha(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};_.Aa=function(a,b,c){return 2>=arguments.length?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};_.Da=function(a,b){b=b||a;for(var c=0,d=0,e={};d<a.length;){var f=a[d++],g=_.Ba(f)?"o"+_.Ca(f):(typeof f).charAt(0)+f;Object.prototype.hasOwnProperty.call(e,g)||(e[g]=!0,b[c++]=f)}b.length=c};
# _.Fa=function(a,b){a.sort(b||_.Ea)};_.Ha=function(a,b){if(!_.ha(a)||!_.ha(b)||a.length!=b.length)return!1;for(var c=a.length,d=caa,e=0;e<c;e++)if(!d(a[e],b[e]))return!1;return!0};_.Ea=function(a,b){return a>b?1:a<b?-1:0};caa=function(a,b){return a===b};_.daa=function(a,b){var c={};(0,_.Ia)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};La=function(a){_.Ja?a(_.Ja):Ka.push(a)};_.Pa=function(){!_.Ja&&_.Ma&&_.Oa((0,_.Ma)());return _.Ja};
# _.Oa=function(a){_.Ja=a;Ka.forEach(function(b){b(_.Ja)});Ka=[]};_.m=function(a){_.Ja&&eaa(a)};_.t=function(){_.Ja&&faa(_.Ja)};gaa=function(){};_.Qa=function(){var a=_.ca.navigator;return a&&(a=a.userAgent)?a:""};Ua=function(a){return Ra?Sa?Sa.brands.some(function(b){return(b=b.brand)&&_.Ta(b,a)}):!1:!1};_.Va=function(a){return _.Ta(_.Qa(),a)};Wa=function(){return Ra?!!Sa&&0<Sa.brands.length:!1};_.Xa=function(){return Wa()?!1:_.Va("Opera")};_.Ya=function(){return Wa()?!1:_.Va("Trident")||_.Va("MSIE")};
# _.Za=function(){return Wa()?!1:_.Va("Edge")};_.$a=function(){return Wa()?Ua("Microsoft Edge"):_.Va("Edg/")};_.ab=function(){return Wa()?Ua("Opera"):_.Va("OPR")};_.bb=function(){return _.Va("Firefox")||_.Va("FxiOS")};_.eb=function(){return _.Va("Safari")&&!(_.cb()||_.db()||_.Xa()||_.Za()||_.$a()||_.ab()||_.bb()||_.Va("Silk")||_.Va("Android"))};_.db=function(){return Wa()?!1:_.Va("Coast")};_.cb=function(){return Wa()?Ua("Chromium"):(_.Va("Chrome")||_.Va("CriOS"))&&!_.Za()||_.Va("Silk")};
# _.fb=function(){return _.Va("Android")&&!(_.cb()||_.bb()||_.Xa()||_.Va("Silk"))};haa=function(a){var b={};a.forEach(function(c){b[c[0]]=c[1]});return function(c){return b[c.find(function(d){return d in b})]||""}};
# iaa=function(a){var b=_.Qa();if("Internet Explorer"===a){if(_.Ya())if((a=/rv: *([\d\.]*)/.exec(b))&&a[1])b=a[1];else{a="";var c=/MSIE +([\d\.]+)/.exec(b);if(c&&c[1])if(b=/Trident\/(\d.\d)/.exec(b),"7.0"==c[1])if(b&&b[1])switch(b[1]){case "4.0":a="8.0";break;case "5.0":a="9.0";break;case "6.0":a="10.0";break;case "7.0":a="11.0"}else a="7.0";else a=c[1];b=a}else b="";return b}var d=RegExp("([A-Z][\\w ]+)/([^\\s]+)\\s*(?:\\((.*?)\\))?","g");c=[];for(var e;e=d.exec(b);)c.push([e[1],e[2],e[3]||void 0]);
# b=haa(c);switch(a){case "Opera":if(_.Xa())return b(["Version","Opera"]);if(_.ab())return b(["OPR"]);break;case "Microsoft Edge":if(_.Za())return b(["Edge"]);if(_.$a())return b(["Edg"]);break;case "Chromium":if(_.cb())return b(["Chrome","CriOS","HeadlessChrome"])}return"Firefox"===a&&_.bb()||"Safari"===a&&_.eb()||"Android Browser"===a&&_.fb()||"Silk"===a&&_.Va("Silk")?(b=c[2])&&b[1]||"":""};
# _.gb=function(a){if(Wa()&&"Silk"!==a){var b=Sa.brands.find(function(c){return c.brand===a});if(!b||!b.version)return NaN;b=b.version.split(".")}else{b=iaa(a);if(""===b)return NaN;b=b.split(".")}return 0===b.length?NaN:Number(b[0])};ib=function(){return Ra?!!Sa&&!!Sa.platform:!1};_.kb=function(){return ib()?"Android"===Sa.platform:_.Va("Android")};lb=function(){return _.Va("iPhone")&&!_.Va("iPod")&&!_.Va("iPad")};_.mb=function(){return lb()||_.Va("iPad")||_.Va("iPod")};
# _.nb=function(){return ib()?"macOS"===Sa.platform:_.Va("Macintosh")};_.jaa=function(){return ib()?"Windows"===Sa.platform:_.Va("Windows")};_.kaa=function(){return ib()?"Chrome OS"===Sa.platform:_.Va("CrOS")};_.ob=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.pb=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.qb=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.laa=function(a){var b=0,c;for(c in a)b++;return b};_.maa=function(a){for(var b in a)return a[b]};
# _.rb=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.sb=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.tb=function(a){for(var b in a)return!1;return!0};_.vb=function(a){var b={},c;for(c in a)b[c]=a[c];return b};_.wb=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<naa.length;f++)c=naa[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};
# oaa=function(a){var b=arguments.length;if(1==b&&Array.isArray(arguments[0]))return oaa.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};yb=function(a){return-1===a.toString().indexOf("`")};_.Bb=function(a){if(a instanceof _.zb)return a.j;throw Error("C");};Db=function(a){return new Cb(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};
# _.Eb=function(a,b){b=void 0===b?paa:b;if(a instanceof _.zb)return a;for(var c=0;c<b.length;++c){var d=b[c];if(d instanceof Cb&&d.qe(a))return new _.zb(a)}};_.Gb=function(a){var b=void 0===b?paa:b;return _.Eb(a,b)||_.Fb};_.Hb=function(a){a instanceof _.zb?a=_.Bb(a):a=qaa.test(a)?a:void 0;return a};_.Jb=function(a){return new _.Ib(a[0].toLowerCase())};
# _.Mb=function(a){var b=_.Kb.apply(1,arguments);if(0===b.length)return _.Lb(a[0]);for(var c=a[0],d=0;d<b.length;d++)c+=encodeURIComponent(b[d])+a[d+1];return _.Lb(c)};_.Ob=function(a,b){b=_.Hb(b);void 0!==b&&(a.href=b)};_.Rb=function(a,b,c){if(b instanceof _.Pb)a.href=_.Qb(b).toString();else{if(-1===raa.indexOf(c))throw Error("G`"+c);b=_.Hb(b);if(void 0===b)return;a.href=b}a.rel=c};
# _.Sb=function(a,b){var c,d;return(b=null==(d=(c=b.document).querySelector)?void 0:d.call(c,a+"[nonce]"))?b.nonce||b.getAttribute("nonce")||"":""};_.saa=function(a){var b=_.Sb("script",a.ownerDocument&&a.ownerDocument.defaultView||window);b&&a.setAttribute("nonce",b)};_.Tb=function(a,b){a.src=_.Qb(b);_.saa(a)};Ub=function(a){return"function"===typeof Symbol&&"symbol"===typeof Symbol()?Symbol():a};_.Vb=function(){var a=Error();taa(a,"incident");_.da(a)};
# _.Wb=function(a){a=Error(a);taa(a,"warning");return a};vaa=function(a){if(!_.uaa)return _.Xb(a);for(var b="",c=0,d=a.length-10240;c<d;)b+=String.fromCharCode.apply(null,a.subarray(c,c+=10240));b+=String.fromCharCode.apply(null,c?a.subarray(c):a);return btoa(b)};_.Yb=function(a){return waa&&null!=a&&a instanceof Uint8Array};Zb=function(){return"function"===typeof BigInt};$b=function(a){return Array.prototype.slice.call(a)};ac=function(a,b,c){return c?a|b:a&~b};
# _.cc=function(a){return!!((0,_.bc)(a)&2)};ec=function(a){(0,_.dc)(a,34);return a};_.xaa=function(a){(0,_.dc)(a,32);return a};yaa=function(a,b){(0,_.fc)(b,(a|0)&-14591)};gc=function(a,b){(0,_.fc)(b,(a|34)&-14557)};_.hc=function(a){a=a>>14&1023;return 0===a?536870912:a};_.ic=function(a){return+!!(a&512)-1};_.jc=function(a){return a.AX===zaa};Baa=function(a){return!(!a||"object"!==typeof a||a.j!==Aaa)};_.kc=function(a){return null!==a&&"object"===typeof a&&!Array.isArray(a)&&a.constructor===Object};
# _.pc=function(a,b,c,d){if(null==a){if(!c)throw Error();}else if("string"===typeof a)a=a?new _.lc(a,_.mc):_.nc();else if(a.constructor!==_.lc)if(_.Yb(a))a=a.length?new _.lc(d?a:new Uint8Array(a),_.mc):_.nc();else{if(!b)throw Error();a=void 0}return a};_.Caa=function(a,b){return!!a&&(Array.isArray(a)?a.includes(b):a.has(b))};_.rc=function(a,b,c){if(!Array.isArray(a)||a.length)return!1;var d=(0,_.bc)(a);if(d&1)return!0;if(!_.Caa(b,c))return!1;(0,_.fc)(a,d|1);return!0};
# _.sc=function(a){if(a&2)throw Error();};_.tc=function(a){if(!Daa)return a.constructor.Ta};_.vc=function(a,b,c){(b=_.uc?b[_.uc]:void 0)?a[_.uc]=$b(b):c&&_.uc&&_.uc in a&&(a[_.uc]=void 0)};_.zc=function(a){var b=0>a;a=Math.abs(a);var c=a>>>0;a=Math.floor((a-c)/4294967296);b&&(c=_.v(wc(c,a)),b=c.next().value,a=c.next().value,c=b);_.xc=c>>>0;_.yc=a>>>0};_.Eaa=function(a,b){var c=b&2147483648;c&&(a=~a+1>>>0,b=~b>>>0,0==a&&(b=b+1>>>0));a=4294967296*b+(a>>>0);return c?-a:a};
# _.Ac=function(a,b){b>>>=0;a>>>=0;if(2097151>=b)var c=""+(4294967296*b+a);else Zb()?c=""+(BigInt(b)<<BigInt(32)|BigInt(a)):(c=(a>>>24|b<<8)&16777215,b=b>>16&65535,a=(a&16777215)+6777216*c+6710656*b,c+=8147497*b,b*=2,1E7<=a&&(c+=Math.floor(a/1E7),a%=1E7),1E7<=c&&(b+=Math.floor(c/1E7),c%=1E7),c=b+Faa(c)+Faa(a));return c};Faa=function(a){a=String(a);return"0000000".slice(a.length)+a};
# Gaa=function(){var a=_.xc,b=_.yc;b&2147483648?Zb()?a=""+(BigInt(b|0)<<BigInt(32)|BigInt(a>>>0)):(b=_.v(wc(a,b)),a=b.next().value,b=b.next().value,a="-"+_.Ac(a,b)):a=_.Ac(a,b);return a};
# _.Bc=function(a){if(16>a.length)_.zc(Number(a));else if(Zb())a=BigInt(a),_.xc=Number(a&BigInt(4294967295))>>>0,_.yc=Number(a>>BigInt(32)&BigInt(4294967295));else{var b=+("-"===a[0]);_.yc=_.xc=0;for(var c=a.length,d=b,e=(c-b)%6+b;e<=c;d=e,e+=6)d=Number(a.slice(d,e)),_.yc*=1E6,_.xc=1E6*_.xc+d,4294967296<=_.xc&&(_.yc+=Math.trunc(_.xc/4294967296),_.yc>>>=0,_.xc>>>=0);b&&(b=_.v(wc(_.xc,_.yc)),a=b.next().value,b=b.next().value,_.xc=a,_.yc=b)}};wc=function(a,b){b=~b;a?a=~a+1:b+=1;return[a,b]};
# _.Cc=function(a){if(null!=a&&"number"!==typeof a)throw Error("R`"+typeof a+"`"+a);return a};_.Dc=function(a){if(null!=a&&"boolean"!==typeof a)throw Error("S`"+Haa(a)+"`"+a);return a};_.Iaa=function(a){if(null==a||"boolean"===typeof a)return a;if("number"===typeof a)return!!a};_.Fc=function(a){var b=typeof a;return"number"===b?Number.isFinite(a):"string"!==b?!1:Jaa.test(a)};_.Gc=function(a){if(!Number.isFinite(a))throw _.Wb("enum");return a|0};
# _.Ic=function(a){return null==a?a:Number.isFinite(a)?a|0:void 0};_.Jc=function(a){if("number"!==typeof a)throw _.Wb("int32");if(!Number.isFinite(a))throw _.Wb("int32");return a|0};_.Mc=function(a){return null==a?a:_.Jc(a)};_.Nc=function(a){if(null==a)return a;if("string"===typeof a){if(!a)return;a=+a}if("number"===typeof a)return Number.isFinite(a)?a|0:void 0};_.Oc=function(a){if(null==a)return a;if("string"===typeof a){if(!a)return;a=+a}if("number"===typeof a)return Number.isFinite(a)?a>>>0:void 0};
# _.Sc=function(a){if(null!=a){var b=!!b;if(!_.Fc(a))throw _.Wb("int64");a="string"===typeof a?_.Pc(a):b?Kaa(a):_.Rc(a)}return a};Tc=function(a){return"-"===a[0]?!1:20>a.length?!0:20===a.length&&184467>Number(a.substring(0,6))};Laa=function(a){return"-"===a[0]?20>a.length?!0:20===a.length&&-922337<Number(a.substring(0,7)):19>a.length?!0:19===a.length&&922337>Number(a.substring(0,6))};
# Maa=function(a){if(0>a){_.zc(a);var b=_.Ac(_.xc,_.yc);a=Number(b);return Number.isSafeInteger(a)?a:b}if(Tc(String(a)))return a;_.zc(a);return 4294967296*_.yc+(_.xc>>>0)};_.Rc=function(a){a=Math.trunc(a);Number.isSafeInteger(a)||(_.zc(a),a=_.Eaa(_.xc,_.yc));return a};_.Uc=function(a){a=Math.trunc(a);return 0<=a&&Number.isSafeInteger(a)?a:Maa(a)};Kaa=function(a){a=Math.trunc(a);if(Number.isSafeInteger(a))a=String(a);else{var b=String(a);Laa(b)?a=b:(_.zc(a),a=Gaa())}return a};
# _.Naa=function(a){a=Math.trunc(a);if(0<=a&&Number.isSafeInteger(a))a=String(a);else{var b=String(a);Tc(b)?a=b:(_.zc(a),a=_.Ac(_.xc,_.yc))}return a};_.Pc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b))return String(b);b=a.indexOf(".");-1!==b&&(a=a.substring(0,b));Laa(a)||(_.Bc(a),a=Gaa());return a};_.Vc=function(a){var b=Math.trunc(Number(a));if(Number.isSafeInteger(b)&&0<=b)return String(b);b=a.indexOf(".");-1!==b&&(a=a.substring(0,b));Tc(a)||(_.Bc(a),a=_.Ac(_.xc,_.yc));return a};
# _.Wc=function(a,b){b=void 0===b?!1:b;if(null==a)return a;if(_.Fc(a))return"string"===typeof a?_.Pc(a):b?Kaa(a):_.Rc(a)};_.Yc=function(a){if("string"!==typeof a)throw Error();return a};_.Zc=function(a){if(null!=a&&"string"!==typeof a)throw Error();return a};Oaa=function(a){return null==a||"string"===typeof a?a:void 0};
# _.bd=function(a,b,c,d){if(null!=a&&"object"===typeof a&&_.jc(a))return a;if(!Array.isArray(a))return c?d&2?_.ad(b):new b:void 0;var e=c=(0,_.bc)(a);0===e&&(e|=d&32);e|=d&2;e!==c&&(0,_.fc)(a,e);return new b(a)};_.ad=function(a){var b=a[Paa];if(b)return b;b=new a;ec(b.na);return a[Paa]=b};_.dd=function(a,b){cd=b;a=new a(b);cd=void 0;return a};
# _.w=function(a,b,c){null==a&&(a=cd);cd=void 0;if(null==a){var d=96;c?(a=[c],d|=512):a=[];b&&(d=d&-16760833|(b&1023)<<14)}else{if(!Array.isArray(a))throw Error("T");d=(0,_.bc)(a);if(d&2048)throw Error("U");if(d&64)return a;d|=64;if(c&&(d|=512,c!==a[0]))throw Error("V");a:{c=a;var e=c.length;if(e){var f=e-1;if(_.kc(c[f])){d|=256;b=f-_.ic(d);if(1024<=b)throw Error("W");d=d&-16760833|(b&1023)<<14;break a}}if(b){b=Math.max(b,e-_.ic(d));if(1024<b)throw Error("X");d=d&-16760833|(b&1023)<<14}}}(0,_.fc)(a,
# d);return a};Raa=function(a,b){return Qaa(b)};Qaa=function(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "boolean":return a?1:0;case "object":if(a)if(Array.isArray(a)){if(_.rc(a,void 0,0))return}else{if(_.Yb(a))return vaa(a);if(a instanceof _.lc)return _.ed(a)}}return a};Saa=function(a,b,c){var d=$b(a),e=d.length,f=b&256?d[e-1]:void 0;e+=f?-1:0;for(b=b&512?1:0;b<e;b++)d[b]=c(d[b]);if(f){b=d[b]={};for(var g in f)b[g]=c(f[g])}_.vc(d,a,!1);return d};
# Taa=function(a,b,c,d,e){if(null!=a){if(Array.isArray(a))a=_.rc(a,void 0,0)?void 0:e&&(0,_.bc)(a)&2?a:_.fd(a,b,c,void 0!==d,e);else if(_.kc(a)){var f={},g;for(g in a)f[g]=Taa(a[g],b,c,d,e);a=f}else a=b(a,d);return a}};_.fd=function(a,b,c,d,e){var f=d||c?(0,_.bc)(a):0;d=d?!!(f&32):void 0;for(var g=$b(a),k=0;k<g.length;k++)g[k]=Taa(g[k],b,c,d,e);c&&(_.vc(g,a,!1),c(f,g));return g};
# Uaa=function(a){_.jc(a)?a=gd(a,_.fd(a.na,Uaa,void 0,void 0,!1),!0):a instanceof _.lc?(a=a.j||"",a="string"===typeof a?a:new Uint8Array(a)):a=_.Yb(a)?new Uint8Array(a):a;return a};_.Vaa=function(a){return _.jc(a)?a.toJSON():Qaa(a)};
# _.hd=function(a,b,c){c=void 0===c?gc:c;if(null!=a){if(waa&&a instanceof Uint8Array)return b?a:new Uint8Array(a);if(Array.isArray(a)){var d=(0,_.bc)(a);if(d&2)return a;b&&(b=0===d||!!(d&32)&&!(d&64||!(d&16)));return b?(0,_.fc)(a,(d|34)&-12293):_.fd(a,_.hd,d&4?gc:c,!0,!0)}_.jc(a)&&(c=a.na,d=(0,_.id)(c),a=d&2?a:_.dd(a.constructor,_.jd(c,d,!0)));return a}};_.jd=function(a,b,c){var d=c||b&2?gc:yaa,e=!!(b&32);a=Saa(a,b,function(f){return _.hd(f,e,d)});(0,_.dc)(a,32|(c?2:0));return a};
# _.kd=function(a){var b=a.na,c=(0,_.id)(b);return c&2?_.dd(a.constructor,_.jd(b,c,!1)):a};_.ld=function(a){var b=a.na,c=(0,_.id)(b);return c&2?a:_.dd(a.constructor,_.jd(b,c,!0))};Xaa=function(a,b,c,d){if(!(4&b))return!0;if(null==c)return!1;!d&&0===c&&(4096&b||8192&b)&&5>(a.constructor[Waa]=(a.constructor[Waa]|0)+1)&&_.Vb();return 0===c?!1:!(c&b)};Yaa=function(a,b,c,d){b=d+_.ic(b);if(!(0>b||b>=a.length||b>=c))return a[b]};
# _.md=function(a,b,c,d,e){var f=_.hc(b);if(c>=f||e){var g=b;if(b&256)e=a[a.length-1];else{if(null==d)return g;e=a[f+_.ic(b)]={};g|=256}e[c]=d;c<f&&(a[c+_.ic(b)]=void 0);g!==b&&(0,_.fc)(a,g);return g}a[c+_.ic(b)]=d;b&256&&(a=a[a.length-1],c in a&&delete a[c]);return b};
# _.Zaa=function(a,b,c,d){var e=b&2,f=_.nd(a,b,c,d);Array.isArray(f)||(f=_.od);var g=!!(b&32),k=(0,_.bc)(f);0===k&&g&&!e?(k|=33,(0,_.fc)(f,k)):k&1||(k|=1,(0,_.fc)(f,k));if(e)k&2||ec(f),Object.freeze(f);else if(2&k||2048&k)f=$b(f),e=1,g&&(e|=32),(0,_.fc)(f,e),_.md(a,b,c,f,d);return f};
# _.td=function(a,b,c){var d=_.pd(),e=a.na,f=(0,_.id)(e);d=2&f?1:d;var g=$aa(e,f,b),k=(0,_.bc)(g);if(Xaa(a,k,void 0,!1)){if(4&k||Object.isFrozen(g))g=$b(g),k=qd(k,f),f=_.md(e,f,b,g);for(var l=a=0;a<g.length;a++){var n=c(g[a]);null!=n&&(g[l++]=n)}l<a&&(g.length=l);k=aba(k,f);k=ac(k,20,!0);k=ac(k,4096,!1);k=ac(k,8192,!1);(0,_.fc)(g,k);2&k&&Object.freeze(g)}rd(k)||(c=k,(a=1===d)?(32&k||(g=$b(g),c=0,f=_.md(e,f,b,g)),k=ac(k,2,!0)):k=sd(k,f,!1),k!==c&&(0,_.fc)(g,k),a&&Object.freeze(g));2===d&&rd(k)&&(g=$b(g),
# k=qd(k,f),k=sd(k,f,!1),(0,_.fc)(g,k),_.md(e,f,b,g));return g};$aa=function(a,b,c,d){a=_.nd(a,b,c,d);return Array.isArray(a)?a:_.od};aba=function(a,b){0===a&&(a=qd(a,b));return a=ac(a,1,!0)};rd=function(a){return!!(2&a)&&!!(4&a)||!!(2048&a)};
# _.ud=function(a,b,c,d){var e=a.na,f=(0,_.id)(e);_.sc(f);if(null==c)return _.md(e,f,b),a;var g=(0,_.bc)(c),k=g,l=!!(2&g)||Object.isFrozen(c),n=!l&&!1;if(Xaa(a,g))for(g=21,l&&(c=$b(c),k=0,g=qd(g,f),g=sd(g,f,!0)),l=0;l<c.length;l++)c[l]=d(c[l]);n&&(c=$b(c),k=0,g=qd(g,f),g=sd(g,f,!0));g!==k&&(0,_.fc)(c,g);_.md(e,f,b,c);return a};_.vd=function(a,b,c,d){var e=a.na,f=(0,_.id)(e);_.sc(f);_.md(e,f,b,("0"===d?0===Number(c):c===d)?void 0:c);return a};
# _.wd=function(a,b,c){for(var d=0,e=0;e<c.length;e++){var f=c[e];null!=_.nd(a,b,f)&&(0!==d&&(b=_.md(a,b,d)),d=f)}return d};_.xd=function(a,b,c,d){a=a.na;var e=(0,_.id)(a),f=_.nd(a,e,c,d);b=_.bd(f,b,!1,e);b!==f&&null!=b&&_.md(a,e,c,b,d);return b};
# _.yd=function(a,b,c,d,e,f,g,k){var l=!!(2&b),n=l?1:e;e=1===n;n=2===n;g=!!g;k&&(k=!l);l=$aa(a,b,d,f);var p=(0,_.bc)(l),q=!!(4&p);if(!q){p=aba(p,b);var r=l,u=b,x;(x=!!(2&p))&&(u=ac(u,2,!0));for(var y=!x,z=!0,D=0,I=0;D<r.length;D++){var M=_.bd(r[D],c,!1,u);if(M instanceof c){if(!x){var J=_.cc(M.na);y&&(y=!J);z&&(z=J)}r[I++]=M}}I<D&&(r.length=I);p=ac(p,4,!0);p=ac(p,16,z);p=ac(p,8,y);(0,_.fc)(r,p);x&&Object.freeze(r)}c=!!(8&p)||e&&!l.length;if(k&&!c){rd(p)&&(l=$b(l),p=qd(p,b),b=_.md(a,b,d,l,f));k=l;c=
# p;for(r=0;r<k.length;r++)p=k[r],u=_.kd(p),p!==u&&(k[r]=u);c=ac(c,8,!0);c=ac(c,16,!k.length);(0,_.fc)(k,c);p=c}rd(p)||(k=p,e?(c=!!(32&p),c||(l=$b(l),k=0,b=_.md(a,b,d,l,f)),p=ac(p,!l.length||16&p&&(!q||c)?2:2048,!0)):p=sd(p,b,g),p!==k&&(0,_.fc)(l,p),e&&Object.freeze(l));n&&rd(p)&&(l=$b(l),p=qd(p,b),p=sd(p,b,g),(0,_.fc)(l,p),_.md(a,b,d,l,f));return l};qd=function(a,b){a=ac(a,2,!!(2&b));a=ac(a,32,!0);return a=ac(a,2048,!1)};sd=function(a,b,c){32&b&&c||(a=ac(a,32,!1));return a};
# _.Ad=function(a,b,c,d,e,f,g){a=a.na;var k=(0,_.id)(a);_.sc(k);b=_.yd(a,k,c,b,2,f,!0);c=null!=d?d:new c;if(g&&("number"!==typeof e||0>e||e>b.length))throw Error();void 0!=e?b.splice(e,g,c):b.push(c);_.cc(c.na)?(0,_.zd)(b,8):(0,_.zd)(b,16)};_.Bd=function(a,b){return null!=a?a:b};_.bba=function(a){if(!Array.isArray(a))throw Error("Y");if(Object.isFrozen(a)||Object.isSealed(a)||!Object.isExtensible(a))throw Error("Z");(0,_.dc)(a,128);return a};
# gd=function(a,b,c){var d=_.tc(a),e=(0,_.id)(c?a.na:b);a=b.length;if(!a)return b;var f;if(_.kc(c=b[a-1])){a:{var g=c;var k={},l=!1,n;for(n in g){var p=g[n];if(Array.isArray(p)){var q=p;if(_.rc(p,d,+n)||Baa(p)&&0===p.size)p=null;p!=q&&(l=!0)}null!=p?k[n]=p:l=!0}if(l){for(var r in k){g=k;break a}g=null}}g!=c&&(f=!0);a--}for(n=_.ic(e);0<a;a--){r=a-1;c=b[r];r-=n;if(!(null==c||_.rc(c,d,r)||Baa(c)&&0===c.size))break;var u=!0}if(!f&&!u)return b;b=Array.prototype.slice.call(b,0,a);g&&b.push(g);return b};
# _.cba=function(a,b){return null==b?_.ad(a.constructor):_.dd(a.constructor,ec(_.bba(b)))};_.Ed=function(a,b){return new _.Dd(a,b)};_.Gd=function(a){return function(b){return _.Fd(a,b)}};_.Hd=function(a,b){b=void 0===b?window:b;b=void 0===b?window:b;return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.Kd=function(a){var b=void 0===b?window:b;return new _.Jd(a,_.Hd(a,b))};
# fba=function(a,b,c){c&&(b=Md(Nd,c,function(){return b}));b=Md(Nd,a,function(){return b});dba.set(a,String(b));(a=b.j)&&Md(eba,a,function(){return b});return b};Md=function(a,b,c){var d=a.get(b);d||(d=c(b),a.set(b,d));return d};_.Pd=function(a,b,c,d,e){e=void 0===e?!1:e;b=new _.Od(a,b,c,void 0===e?!1:e);return fba(a,b,d)};_.A=function(a,b){return _.Pd(a,a,b)};_.Sd=function(a){if(!_.Qd.has("startup"))throw Error("ua`startup");_.gba.has("startup")?a.apply():_.Rd.startup.push(a)};
# _.Td=function(a,b){b.hasOwnProperty("displayName")||(b.displayName=a.toString());b[hba]=a};iba=function(a){a=a[hba];return a instanceof _.Od?a:null};_.kba=function(a){if(a instanceof _.Ud)return a.j;if(a instanceof _.Od)return a;if("function"===typeof a)return _.jba(_.Vd.kb(),a)};_.lba=function(a){return(a=_.kba(a))?_.Wd(_.Xd.kb(),a):void 0};_.Zd=function(a){Yd.push(a)};_.ae=function(a){_.Ia(Yd,function(b){_.$d(b,a)})};
# mba=function(){if(be)for(var a=be.o,b=0;b<Yd.length;b++){var c=Yd[b];_.sa(a,c)||a.push(c)}};nba=function(){return _.ce(Yd,function(a){return a.j})};_.ge=function(a,b){var c=_.de[a];c||(c=_.de[a]=[]);c.push(b)};_.oba=function(){return lb()||_.Va("iPod")?4:_.Va("iPad")?5:_.kb()?he()?3:2:_.ie()?1:0};
# qba=function(a){var b="";var c=_.ca._F_jsUrl;if("undefined"!==typeof document&&document&&document.getElementById&&(a=document.getElementById(a))){var d=a.tagName.toUpperCase();if("SCRIPT"==d||"LINK"==d)b=a.src?a.src:a.getAttribute("href")}if(c&&b){if(c!=b)throw Error("Ba`"+c+"`"+b);b=c}else b=c||b;if(!pba(b))throw Error("Ca");return b};je=function(a){return Md(rba,a.toString(),function(){return new Set})};
# _.me=function(a,b,c,d,e){a=_.Pd(a,b,d?[d]:void 0,void 0,ke);e&&le(e).add(a);_.Xd.kb().register(a,new sba(a,je(a),c?je(c):new Set,le(a),c?le(c):new Set,d));return a};ne=function(a,b){je(b).add(a)};_.pe=function(a,b){if(!b&&a.hasAttribute("jsshadow"))return null;for(b=0;a=_.oe(a);){if(a&&void 0===a&&0<b){tba||(tba=!0);break}if(a.hasAttribute("jsslot"))b+=1;else if(a.hasAttribute("jsshadow")&&0<b){--b;continue}if(0>=b)return a}return null};
# _.oe=function(a){return a?_.qe(a)?_.qe(a):a.parentNode&&11===a.parentNode.nodeType?a.parentNode.host:_.se(a):null};_.te=function(a,b,c,d){for(c||(a=_.pe(a,d));a&&void 0!==a;){if(b(a))return a;a=_.pe(a,d)}return null};_.uba=function(a){var b;_.te(a,function(c){return _.qe(c)?(b=_.qe(c),!0):!1},!0);return b||a};vba=function(a){return _.ue(a)?"coFSxe"===a.getAttribute("jsname"):!1};_.wba=function(a){return _.ve(a,vba)};
# xba=function(a){if(!a)return[];var b=(_.we.has(a)?_.we.get(a):[]).filter(_.wba);_.we.set(a,b);return b};_.xe=function(a){"__jsaction"in a&&delete a.__jsaction};_.ze=function(a){return _.Ba(a)&&void 0!==a.Ib&&a.Ib instanceof _.ye&&void 0!==a.qb&&(void 0===a.nc||a.nc instanceof _.B)?!0:!1};yba=function(a){var b=a.RWa;_.ze(a)&&(b=a.metadata?!a.metadata.fatal:void 0);return b};
# zba=function(a,b){if(!a)return _.Ae();var c=a.Ij;return _.ze(a)&&(c=a.metadata?a.metadata.Ij:void 0,a.metadata&&a.metadata.yS)?_.Be(b,{service:{Gl:_.Ce}}).then(function(d){d=d.service.Gl;for(var e=_.v(a.metadata.yS),f=e.next();!f.done;f=e.next())f=f.value,_.De(d.get(f.zVa))&&(c=f.Ij);return c}):_.Ae(c)};
# Bba=function(a,b,c){return zba(a,c).then(function(d){if(void 0==d||0>d)return b;var e=!1;b.then(function(){e=!0},function(){});d=_.Ee(d,_.Ae(null));a.metadata&&(a.metadata.wI=!1);d.then(function(){a.metadata&&(a.metadata.wI=!e)});return _.Aba([b,d])})};Cba=function(a,b){return yba(a)?b.Pe(function(){return _.Ae(null)}):b};
# Gba=function(a,b){return _.ze(a)&&a.metadata&&a.metadata.uK?b.then(function(c){if(!c&&a.metadata&&a.metadata.wI){c=new Dba;var d=new _.Fe;c.j=void 0;var e="type.googleapis.com";e=void 0===e?"type.googleapis.com/":e;"/"!==e.substr(-1)&&(e+="/");_.Ge(d,1,e+"wiz.data.clients.WizDataTimeoutError");_.He(d,2,c,!1);return _.Eba(_.Fba(new _.Je,2),[d])}},function(c){if(c instanceof _.Ke)return c.status}):b};Iba=function(a,b){var c=_.Be(a,{service:{V0:_.Hba}});return _.qb(b,function(d){return c.then(function(e){return e.service.V0.o(d)})})};
# _.Le=function(){};Jba=function(a){if(a instanceof Object&&!Object.isFrozen(a)){var b=_.Me(a.fileName||a.filename||a.sourceURL||_.ca.$googDebugFname||location.href);try{a.fileName=b}catch(c){}}};_.Ne=function(a,b){_.Kba(null,a,void 0===b?"unknown":b)};Mba=function(){var a={};a.location=_.Me(location);if(Lba())try{a["top.location"]=_.Me(top.location)}catch(c){a["top.location"]="[external]"}else a["top.location"]="[external]";for(var b in Oe)try{a[b]=Oe[b].call()}catch(c){a[b]="[error] "+c.message}return a};
# Uba=function(a,b){Pe.init();a&&(a=new Qe(a,void 0,!0),a=new Nba(a),_.Re.j=a,b&&(a.j=b),Oba(a));var c=function(e){return _.Ne(e,"severe")},d=null;b=function(e){_.ca.$googDebugFname&&e&&e.message&&!e.fileName&&(e.message+=" in "+_.ca.$googDebugFname);d?e&&e.message&&(e.message+=" [Possibly caused by: "+d+"]"):d=String(e);c(e)};_.Se("_DumpException",b);_.Se("_B_err",b);_.Ia([_.ca].concat([]),_.Te(Pba,_.Te(Qba,!0,c),!0));28<=_.gb("Chromium")||14<=_.gb("Firefox")||11<=_.gb("Internet Explorer")||_.gb("Safari");
# 9>=_.gb("Internet Explorer")||(b=new Ue(c),b.o=!0,b.j=!0,Rba(b),Ve(b,"setTimeout"),Ve(b,"setInterval"),Sba(b),Tba(b),_.Re.o=b)};Qba=function(a,b,c){_.Ta(c.message,"Error in protected function: ")||(c.error&&c.error.stack?b(c.error):a||b(c))};Yba=function(a){var b=_.We(_.Kd("Im6cmf"))+"/jserror";Uba(b,a);a=_.Vba(_.Ye(_.Kd("cfb2h"),""));Oe.buildLabel=a;null!==Wba&&_.Re.j&&(Xba&&(_.Re.j.H=!0),_.Re.j.o.push(Wba))};_.Ze=function(a){var b=Nd.get(a);return b?b:(b=new _.Od(a,a,[]),fba(a,b),b)};
# _.bf=function(a,b){a.__soy_skip_handler=b};cf=function(){};$ba=function(a,b,c){a=a.style;if("string"===typeof c)a.cssText=c;else{a.cssText="";for(var d in c)if(Zba.call(c,d)){b=a;var e=d,f=c[d];0<=e.indexOf("-")?b.setProperty(e,f):b[e]=f}}};
# aca=function(a,b,c){var d=typeof c;"object"===d||"function"===d?a[b]=c:null==c?a.removeAttribute(b):(d=0===b.lastIndexOf("xml:",0)?"http://www.w3.org/XML/1998/namespace":0===b.lastIndexOf("xlink:",0)?"http://www.w3.org/1999/xlink":null)?a.setAttributeNS(d,b,c):a.setAttribute(b,c)};_.bca=function(){var a=new cf;a.__default=aca;a.style=$ba;return a};cca=function(a,b,c,d,e){return b==c&&d==e};_.hf=function(a){for(var b=_.df,c=_.ff();c!==a;){var d=c.nextSibling;b.removeChild(c);_.gf.o.push(c);c=d}};
# _.ff=function(){return _.jf?_.jf.nextSibling:_.df.firstChild};
# _.fca=function(a,b){b=void 0===b?{}:b;var c=void 0===b.matches?cca:b.matches;return function(d,e,f){var g=_.gf,k=_.kf,l=_.lf,n=_.pf,p=_.jf,q=_.df,r=_.qf;_.kf=d.ownerDocument;_.gf=new dca(d);_.qf=c;_.pf=[];_.jf=null;var u=_.df=d.parentNode,x,y=eca.call(d);if((x=11===y.nodeType||9===y.nodeType?y.activeElement:null)&&d.contains(x)){for(y=[];x!==u;)y.push(x),x=x.parentNode||(u?x.host:null);u=y}else u=[];_.lf=u;try{return a(d,e,f)}finally{d=_.gf,_.rf&&0<d.j.length&&(0,_.rf)(d.j),_.sf&&0<d.o.length&&(0,_.sf)(d.o),
# _.kf=k,_.gf=g,_.qf=r,_.pf=n,_.jf=p,_.df=q,_.lf=l}}};_.gca=function(a){return _.fca(function(b,c,d){_.df=_.jf=b;_.jf=null;c(d);_.hf(null);_.jf=_.df;_.df=_.df.parentNode;return b},a)};tf=function(a){a=a.__soy;a.f0();return a};ica=function(a){for(;a&&!a.NF&&!hca(a);)a=a.parentElement;return{element:a,DI:a.NF}};
# jca=function(){_.uf({soy:function(a){var b=a.T?a.T().el():a.vi();var c=b.__soy?tf(b):null;if(c)return _.Ae(c);var d=ica(b),e=d.element;e.lz||(e.lz=new Set);var f=e.lz;c=new Set;for(var g=_.v(f),k=g.next();!k.done;k=g.next())k=k.value,_.vf(b,k)&&c.add(k);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.DI?d.DI.then(function(){f.clear();var l=b.__soy?tf(b):null;if(l)return l;e.__soy.render();return tf(b)}):_.wf([a.Bg(_.xf,d.element),_.Be(a,{service:{mx:_.yf}})]).then(function(l){var n=l[1].service.mx;
# return l[0].cU().then(function(p){d.element.getAttribute("jsrenderer");f.clear();e.__incrementalDOMData||n.SV(e,p.template,p.args);if((!b.__soy||!tf(b))&&e.__incrementalDOMData){p="Hydration source "+(document.body.contains(e)?"in dom":"not in dom")+";";var q="El source "+(document.body.contains(b)?"in dom":"not in dom");_.da(Error("Sa`"+p+"`"+q+"`"+(b.getAttribute("jscontroller")||b.getAttribute("jsmodel"))));return null}return tf(b)})});b.lz=c;b.NF=a;return a.then(function(l){return l})}})};
# zf=function(a,b){a:{if("function"===typeof window.Event)try{var c=new Event(a,{bubbles:!1,cancelable:!0});break a}catch(d){}c=document.createEvent("Event");c.initEvent(a,!1,!0)}a=c;a.AVa=b;return a};Af=function(){try{if("function"===typeof window.EventTarget)return new EventTarget}catch(a){}try{return document.createElement("div")}catch(a){}return null};
# kca=function(a){var b,c,d,e;return new Bf(null!=(d=null==(b=a.mf())?void 0:b.name)?d:"",null!=(e=null==(c=a.mf())?void 0:c.element)?e:null,a.j.event,a.j.timeStamp,a.Qj(),a.j.targetElement)};lca=function(a,b){for(;a&&a.nodeType===Node.ELEMENT_NODE;a=a.parentNode)b(a)};mca=function(a){var b=this.getAttribute(a);Element.prototype.setAttribute.apply(this,arguments);var c=this.getAttribute(a);_.Cf(this,Df,{name:a,qq:c,b_:b},!1)};
# nca=function(a){var b=this.getAttribute(a);Element.prototype.removeAttribute.apply(this,arguments);_.Cf(this,Df,{name:a,qq:null,b_:b},!1)};Ff=function(){return!!(window.performance&&window.performance.mark&&window.performance.measure&&window.performance.clearMeasures&&window.performance.clearMarks)};oca=function(a,b){for(var c=0;c<b.length;c++)try{var d=b[c].j(a);if(null!=d&&d.abort)return d}catch(e){_.da(e)}};pca=function(a,b){for(var c=0;c<b.length;c++)try{b[c].o(a)}catch(d){_.da(d)}};
# ...
# !c&&!d),_.Y(a.v,"gb_We",c||d));a.i&&(c=a.i.i,_.cf(c,e),_.$e(c,b),xi(a.i)?_.V("gb_Hd").appendChild(c):a.o.appendChild(c),a.i.isVisible("menu")||a.i.isVisible("back"))&&(b=!xi(a.i),c=a.i.rb(),b&&!c&&a.ya?a.i.open():!b&&c&&a.i.close());Zi(a)},Qi=function(a,b){var c=_.V("gb_Nc",a.C.H());_.Y(c,"gb_q",!b);a=_.V("gb_od",a.C.H());null!=a&&_.Y(a,"gb_7d",!b)},Mi=function(a,b,c){var d=320,e=_.ng(_.he(a.j,29),0);0<e&&(d=e);e=d+2*Math.max(b,c);b=d+b+c;return e!=b&&a.X?[{id:1,max:b},{id:2,max:e},{id:3}]:[{id:1,
# max:b},{id:3}]},Ki=function(a,b){if(a=_.V(b?"gb_he":"gb_ie",a.o)){var c=a.offsetWidth;_.ac(a.children,function(d){_.W(d,"gb_q")&&(c-=d.offsetWidth)});return c}return 0},Yi=function(a){var b=_.V("gb_he",a.o),c=_.V("gb_ie",a.o),d=[];b&&_.ac(b.children,function(e){d.push(e)});_.w(_.G(a.j,7),!1)&&(a=_.V("gb_He",a.v))&&(a=_.V("gb_Je",a),a.j=!0,d.push(a));c&&_.ac(c.children,function(e){d.push(e)});return d};Z.prototype.Rb=function(){Pi(this,this.F.i);this.i&&_.$i(this,this.i.rb(),!1);this.dispatchEvent("ffc")};
# _.$i=function(a,b,c){a.i&&(xi(a.i)&&(c=b=!1),a=document.body,_.Y(a,"gb_ce",b),_.Y(a,"gb_be",c))};Z.prototype.oc=function(){_.$i(this,!0,!0)};Z.prototype.Ib=function(){_.$i(this,!1,!0)};Z.prototype.qc=function(){var a=xi(this.i),b=this.i.i;a?_.V("gb_Hd").appendChild(b):this.o.appendChild(b)};_.Xi=function(a){return!!a.i&&_.W(a.A,"gb_Cd")};
# Z.prototype.G=function(a){var b=!1;switch(a){case "back":this.O=!0;zi(this.i);yi(this.i,"back");b=!0;break;case "close":this.O=!0;zi(this.i);yi(this.i,"close");b=!0;break;case "default":this.O=!1;Wi(this,this.F.i)||this.xc?(this.i&&!this.i.isVisible("menu")&&(zi(this.i),yi(this.i,"menu")),b=!0):(this.i&&this.i.isVisible("back")&&zi(this.i),this.i&&this.i.isVisible("menu")?(a=this.i,a.close(),_.$e(a.H(),"gb_q"),!_.W(a.U,"gb_q")&&_.bf(a.H(),"gb_Tc")):(a=_.V("gb_Oc",this.o))&&_.$e(a,"gb_q"),b=!1);break;
# case "none":this.O=!0,zi(this.i),b=!1}null!=this.B&&_.Y(this.B,"gb_hd",b)};var Wi=function(a,b){var c="gb_Ra"==b;b="gb_vd"==b;var d=_.w(_.G(a.j,5),!1),e=_.w(_.G(a.j,2),!1);return!(_.w(_.G(a.j,10),!1)||a.Y||_.w(_.G(a.j,44),!1))&&e&&(c||b&&(d||a.T))};Z.prototype.Fb=function(){return this.o.offsetHeight};var Zi=function(a){var b=a.o.offsetHeight+"px";a.Ea!=b&&(a.Ea=b,a.Sa&&(a.Sa.style.height=b),a.dispatchEvent("resize"))};Z.prototype.Cc=function(){this.M&&Zi(this)};
# Z.prototype.Pb=function(){if(!this.M){var a=_.Me("DIV");_.af(a,["gb_yd","gb_kd"]);aj(a,Ri(this));a.style.backgroundColor=this.o.style.backgroundColor;this.ea.push(a);var b=this.D;b.parentNode&&b.parentNode.insertBefore(a,b.nextSibling);this.M=a}return this.M};Z.prototype.Ec=function(){_.Dg(this.M);this.M=null;Zi(this)};Z.prototype.Ra=function(a){2==a&&(a=0);for(var b=0;b<this.ea.length;b++)aj(this.ea[b],a);Si(this,a)};
# var Si=function(a,b){if(a.C){if(2==b){b=_.x(_.K(a.j,24),"");var c=_.x(_.K(a.j,27),"")}else 1==b?(b=_.x(_.K(a.j,23),""),c=_.x(_.K(a.j,26),"")):(b=_.x(_.K(a.j,22),""),c=_.x(_.K(a.j,25),""));""==b&&""==c||ci(a.C,b,c)}},Ri=function(a){a=a.ea[0];return a.classList.contains("gb_Pc")?1:a.classList.contains("gb_Md")?2:0},aj=function(a,b){_.cf(a,["gb_Md","gb_Pc"]);1==b?_.$e(a,"gb_Pc"):2==b&&_.$e(a,"gb_Md")};Z.prototype.oa=function(a){this.o.style.backgroundColor=a};Z.prototype.ob=function(){return this.o.style.backgroundColor};
# Z.prototype.ka=function(){var a=_.Ud("dd");_.Nh(a)&&_.Nh(a).vd(!1);_.ei(a,null)};Z.prototype.Uc=function(a){Li(this,a-8-10);Vi(this)};var Li=function(a,b){null==a.v?a.N.log(Error("na")):a.X?a.N.log(Error("oa")):a.La=0>b?0:b},Vi=function(a){null!=a.B&&("gb_Ra"==a.F.i?_.Wg(a.B,"min-width",""):null!=a.La&&_.Wg(a.B,"min-width",a.La+"px"))};Z.prototype.Vc=function(a){_.Y(_.V("gb_Hc",this.D),"gb_q",!a)};Z.prototype.Mc=function(){fi(function(a){a&&a.Mc()})};
# Z.prototype.Fc=function(a){a&&(_.Vh(_.V("gb_Od"),a),_.pd.i().j.then(function(b){return void b.Qd(a)}))};var Ni=[{id:"gb_Ra",max:599},{id:"gb_vd",max:1023},{id:"gb_1c"}];var bj;_.X.prototype.za=_.fe(function(a,b,c,d,e){return a.call(this,b,_.fe(ai,c),d,e)},_.X.prototype.listen);_.X.prototype.zb=_.X.prototype.oi;var cj=_.V("gb_Qa");
# if(null==cj)bj=null;else{var dj=_.I(_.rd,_.Rd,6)||new _.Rd,ej=new Z(cj,dj,_.vd,_.V("gb_ud"));_.E("gbar.P",Z);Z.prototype.pa=Z.prototype.Fb;Z.prototype.pb=Z.prototype.Mj;Z.prototype.pc=Z.prototype.Ra;Z.prototype.pd=Z.prototype.oa;Z.prototype.pe=Z.prototype.Pb;Z.prototype.pf=Z.prototype.Cc;Z.prototype.pg=Z.prototype.Ec;Z.prototype.ph=Z.prototype.tg;Z.prototype.pi=Z.prototype.ka;Z.prototype.pj=Z.prototype.Uc;Z.prototype.pk=Z.prototype.Vc;Z.prototype.pl=Z.prototype.Fc;Z.prototype.pm=Z.prototype.G;Z.prototype.pn=
# Z.prototype.ob;Z.prototype.po=Z.prototype.Kj;Z.prototype.pp=Z.prototype.Xa;Z.prototype.pq=Z.prototype.Mc;_.pd.i().v.resolve(ej);bj=ej}_.fj=bj;
# }catch(e){_._DumpException(e)}
# try{
# _.gj=function(a,b){return _.N(a,36,b)};
# }catch(e){_._DumpException(e)}
# try{
# var hj=document.querySelector(".gb_b .gb_d"),ij=document.querySelector("#gb.gb_Xc");hj&&!ij&&_.Md(_.wd,hj,"click");
# }catch(e){_._DumpException(e)}
# try{
# _.pd.i().v.then(function(a){if(a){var b=_.V("gb_Hc",a.D);b&&(b=new _.zh(b,_.vd),a.Jj(b))}});
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><c-wiz c-wiz="" class="zQTmif SSPGKf" data-node-index="0;0" data-ogpc="" data-p='%.@."코로나",[["ko","KR",["FINANCE_TOP_INDICES","SPORTS_FULL_COVERAGE","WEB_TEST_1_0_0"],null,null,1,1,"KR:ko",null,null,null,null,null,null,null,false],"ko","KR",true,[2,4,8,32],1,true,"629604935",false,false,null,false],1,true]' jsdata="deferred-i5" jslog="88503; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLFtdXQ==; track:vis" jsmodel="hc6Ubd" jsname="a9kxte" jsrenderer="vBVNjc" view=""><div class="T4LgNb" jsname="a9kxte"><div class="VjFXz"></div><main class="IKXQhd" data-n-tid="26" jsaction="rcuQ6b:npT2md;" jscontroller="aXyUec"><div class="fuAp6" jsname="ReIlqe"></div><div class="UW0SDc" jslog="94187; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLFtdXQ=="><c-wiz autoupdate="" c-wiz="" class="D9SJMe" data-n-ct="" data-n-vio="100" data-node-index="2;0" data-p='%.@.[["ko","KR",["FINANCE_TOP_INDICES","SPORTS_FULL_COVERAGE","WEB_TEST_1_0_0"],null,null,1,1,"KR:ko",null,null,null,null,null,null,null,false],"ko","KR",true,[2,4,8,32],1,true,"629604935",false,false,null,false],"코로나"]' jsaction="rcuQ6b:npT2md;" jscontroller="Ck11W" jsdata="deferred-i6" jsmodel="hc6Ubd" jsrenderer="Kyqkid" jsshadow=""><c-wiz c-wiz="" class="PO9Zff Ccj79 kUVvS" data-node-index="1;0" data-p="%.@.]" jsdata="deferred-i7" jslog="93789; 3:...; track:vis; index:0" jsmodel="hc6Ubd" jsrenderer="ARwRbe" jsshadow=""><div class="nTN4Wc"><hr class="Cc1bcb"/></div><c-wiz c-wiz="" class="XBspb" data-node-index="1;0" data-p="%.@.]" jsdata="deferred-i8" jsmodel="hc6Ubd FSc7tf" jsrenderer="NTi1Eb" jsshadow=""><article class="IFHyqb DeXSAc" data-n-cvid="i9" data-n-et="107" data-n-ham="true" data-n-suav="false" jsaction="rcuQ6b:npT2md;" jscontroller="BoFkO" jsdata="oM6qxc;CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx;4" jslog="85008; 3:...; track:vis; index:0" jsmodel="hT8rr" ve-visible="false"><div class="m5k28"><div class="XlKvRb" jsaction="click:KjsqPd;"><a aria-hidden="true" class="WwrzSb" href="./articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx?hl=ko&amp;gl=KR&amp;ceid=KR%3Ako" jslog="95014; 5:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCwiaHR0cHM6Ly93d3cueXRuLmNvLmtyL19sbi8wMTA1XzIwMjQwNTA0MDYyOTM1OTU1MSJd; track:click,vis" jsname="hXwDdf" tabindex="-1" target="_blank"></a></div><div class="B6pJDd"><div class="IL9Cne"><div class="MCAGUe"><div class="oovtQ"><img alt="" class="qEdqNd" loading="lazy" src="https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL" srcset="https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL 1x, https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL 2x"/><div class="a7P8l"><div class="vr1PYe" data-n-tid="9">YTN</div></div></div><div class="hLNLFf JfXTR"><div jsaction="TDui6d:BgNF9e;EDR5Je:s1jPxd;dcnbp:ZElhof;FzgWvd:RmtIce;" jscontroller="edeRg" jsdata="oM6qxc;CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx;4" jslog="109017; track:click" jsmodel="DBqG5"><div class="VfPpkd-xl07Ob-XxIAqe-OWXEXe-oYxtQd" data-is-menu-dynamic="true" jsaction="JIbuQc:aj0Jcf(WjL7X); keydown:uYT2Vb(WjL7X);xDliB:oNPcuf;SM8mFd:li9Srb;iFFCZc:NSsOUb;Rld2oe:NSsOUb" jscontroller="wg1P6b" jsname="Li8BO" jsshadow=""><div jsname="WjL7X" jsslot=""><span data-is-tooltip-wrapper="true"><button aria-expanded="false" aria-haspopup="menu" aria-label="더보기 - 코로나19·사스·메르스,  ...
# c.initAft=function(){f=0;e=Array.prototype.slice.call(document.getElementsByTagName("img")).filter(function(a){return!!a.getAttribute("data-iml")});[].forEach.call(document.getElementsByTagName("img"),function(a){try{_recordIsAboveFold(a)}catch(b){throw b.message=a.hasAttribute("data-iid")?b.message+"\nrecordIsAboveFold error for defer inlined image":b.message+("\nrecordIsAboveFold error for img element with <src: "+a.src+">"),b;}});if(0===d.length)c.onaft(f)};}).call(this);
# initAft()</script><script id="_ij" nonce="lsVcNpukXBCWP_XuCK6YlQ">window.IJ_values = ['\/\/www.google.com\/advanced_search?hl\x3dko\x26fg\x3d1\x26q\x3d%EC%BD%94%EB%A1%9C%EB%82%98',[null,null,"",false,null,null,null,false],'0','www.google.com','https:\/\/news.google.com\/', null ,'boq_dotssplashserver_20240430.13_p0','news.google.com','KR:ko', 0.0 , 1.0 , 0.0 , null , null , null ,'','lsVcNpukXBCWP_XuCK6YlQ','i-E0ipfJ06SbztK3cII8eg','DEFAULT','한국어 (대한민국)','', 2024.0 ,'https:\/\/news.google.com\/search', null ,'ltr', false ,'https:\/\/accounts.google.com\/AccountChooser?continue\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26hl\x3dko','\/\/accounts.google.com\/ServiceLogin?continue\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26hl\x3dko','https:\/\/accounts.google.com\/ServiceLogin?hl\x3dko\x26continue\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko','https:\/\/accounts.google.com\/SignOutOptions?continue\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko','KR','ko', true , false , true , false , false , false , false , false , true , false , false , true ,'ko','ko','한국어','\/\/www.google.com\/preferences?hl\x3dko\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26lang\x3d1#languages','us_2020_elections,us_2020_elections_local_news_with_summary_submix;gemini_briefing_local_v2,gemini_briefing_local_news_with_summary_submix','ko','\/\/support.google.com\/websearch\/answer\/179386?source\x3dg\x26hl\x3dko','\/\/www.google.com','https:\/\/goto2.corp.google.com\/mdtredirect?data_id_filter\x3dnews.google.com\x26system_name\x3ddots-splash-server',[], null , null , null , null ,'','https:\/\/myaccount.google.com\/privacypolicy?hl\x3dko','\/\/www.google.com\/history\/optout?hl\x3dko', false ,'\/\/www.google.com\/setprefs?sig\x3d0_8lutJXOBRlA71fYxt8f-BWQwWzs%3D\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26safeui\x3dimages','\/\/www.google.com\/setprefs?sig\x3d0_8lutJXOBRlA71fYxt8f-BWQwWzs%3D\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26safeui\x3don','\/\/www.google.com\/safesearch?hl\x3dko\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko','\/\/www.google.com\/setprefs?sig\x3d0_8lutJXOBRlA71fYxt8f-BWQwWzs%3D\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26safeui\x3doff', null ,'\/\/support.google.com\/websearch\/?source\x3dg\x26hl\x3dko','\/\/www.google.com\/history\/optout?hl\x3dko','KR','\/\/www.google.com\/preferences?hl\x3dko\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26fg\x3d1', 1.0 ,'\/\/www.google.com\/setprefs?cs\x3d2\x26sig\x3d0_8lutJXOBRlA71fYxt8f-BWQwWzs%3D\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26hl\x3dko','\/\/www.google.com\/setprefs?cs\x3d1\x26sig\x3d0_8lutJXOBRlA71fYxt8f-BWQwWzs%3D\x26prev\x3dhttps:\/\/news.google.com\/search?q%3D%25EC%25BD%2594%25EB%25A1%259C%25EB%2582%2598%26hl%3Dko%26gl%3DKR%26ceid%3DKR:ko\x26hl\x3dko','\/\/support.google.com\/googleshopping?hl\x3dko','\/\/shopping.google.com\/settings', false , true , null , 0.0 , false , false , false , false , true ,'KR', false , true ,[[["gl","KR"],["hl","ko"]]],'\x26gl\x3dKR\x26hl\x3dko','https:\/\/myaccount.google.com\/termsofservice?hl\x3dko', null , false , null ,'\/\/www.googl ...
# try{
# if(_.fj){var jj;if(jj=_.K(_.fj.j,3))for(var kj=_.Dh(jj),lj=0;lj<kj.length;lj++){var mj=kj[lj];if(_.Jh&&mj.dataset)mj.dataset.ogpc="";else{if(/-[a-z]/.test("ogpc"))throw Error("Q");mj.setAttribute("data-"+_.gi("ogpc"),"")}}_.$i(_.fj,!!_.fj.i&&_.fj.i.rb(),!1)};
# }catch(e){_._DumpException(e)}
# try{
# _.nj=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.oj=function(a){if(!a)return null;a=_.K(a,4);var b;null===a||void 0===a?b=null:b=_.te(a);return b};_.pj=function(a){this.J=_.v(a)};_.z(_.pj,_.R);_.qj=function(a,b){return(b||document).getElementsByTagName(String(a))};
# }catch(e){_._DumpException(e)}
# try{
# var sj=function(a,b,c){a<b?rj(a+1,b):_.vd.log(Error("pa`"+a+"`"+b),{url:c})},rj=function(a,b){if(tj){var c=_.Me("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.re(tj);_.nj(c);c.onerror=_.fe(sj,a,b,c.src);_.qj("HEAD")[0].appendChild(c)}},uj=function(a){this.J=_.v(a)};_.z(uj,_.R);var vj=_.I(_.rd,uj,17)||new uj,wj,tj=(wj=_.I(vj,_.pj,1))?_.oj(wj):null,xj,yj=(xj=_.I(vj,_.pj,2))?_.oj(xj):null,zj=function(){rj(1,2);if(yj){var a=_.Me("LINK");a.setAttribute("type","text/css");a.rel="stylesheet";if(_.fa("stylesheet","stylesheet")){a.href=_.re(yj).toString();var b=_.He(a.ownerDocument&&a.ownerDocument.defaultView);b&&a.setAttribute("nonce",b)}else a.href=yj instanceof _.qe?_.re(yj).toString():_.Ie(yj);(b=_.He())&&a.setAttribute("nonce",b);_.qj("HEAD")[0].appendChild(a)}};(function(){var a=_.sd();if(_.G(a,18))zj();else{var b=_.he(a,19)||0;window.addEventListener("load",function(){window.setTimeout(zj,b)})}})();
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><div ng-non-bindable=""><div class="gb_Be">검색</div><div class="gb_De">검색어 지우기</div><div class="gb_Ce">검색 닫기</div><div class="gb_m">Google 앱</div><div class="gb_Qc">기본 메뉴</div></div>

# %%
# 내부HTML 전체 구조파악 :
## Type1: soup.find_all('div', class_='xrnccd')[0]
## Type2: soup.select('div.xrnccd')[0]

# %%
news_items = soup.select('div.UW0SDc')

# %%
print(len(news_items))
# Out:
# 1

# %%
print(news_items[0])
# Out:
# <div class="UW0SDc" jslog="94187; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLFtdXQ=="><c-wiz autoupdate="" c-wiz="" class="D9SJMe" data-n-ct="" data-n-vio="100" data-node-index="2;0" data-p='%.@.[["ko","KR",["FINANCE_TOP_INDICES","SPORTS_FULL_COVERAGE","WEB_TEST_1_0_0"],null,null,1,1,"KR:ko",null,null,null,null,null,null,null,false],"ko","KR",true,[2,4,8,32],1,true,"629604935",false,false,null,false],"코로나"]' jsaction="rcuQ6b:npT2md;" jscontroller="Ck11W" jsdata="deferred-i6" jsmodel="hc6Ubd" jsrenderer="Kyqkid" jsshadow=""><c-wiz c-wiz="" class="PO9Zff Ccj79 kUVvS" data-node-index="1;0" data-p="%.@.]" jsdata="deferred-i7" jslog="93789; 3:...; track:vis; index:0" jsmodel="hc6Ubd" jsrenderer="ARwRbe" jsshadow=""><div class="nTN4Wc"><hr class="Cc1bcb"/></div><c-wiz c-wiz="" class="XBspb" data-node-index="1;0" data-p="%.@.]" jsdata="deferred-i8" jsmodel="hc6Ubd FSc7tf" jsrenderer="NTi1Eb" jsshadow=""><article class="IFHyqb DeXSAc" data-n-cvid="i9" data-n-et="107" data-n-ham="true" data-n-suav="false" jsaction="rcuQ6b:npT2md;" jscontroller="BoFkO" jsdata="oM6qxc;CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx;4" jslog="85008; 3:...; track:vis; index:0" jsmodel="hT8rr" ve-visible="false"><div class="m5k28"><div class="XlKvRb" jsaction="click:KjsqPd;"><a aria-hidden="true" class="WwrzSb" href="./articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx?hl=ko&amp;gl=KR&amp;ceid=KR%3Ako" jslog="95014; 5:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCwiaHR0cHM6Ly93d3cueXRuLmNvLmtyL19sbi8wMTA1XzIwMjQwNTA0MDYyOTM1OTU1MSJd; track:click,vis" jsname="hXwDdf" tabindex="-1" target="_blank"></a></div><div class="B6pJDd"><div class="IL9Cne"><div class="MCAGUe"><div class="oovtQ"><img alt="" class="qEdqNd" loading="lazy" src="https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL" srcset="https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL 1x, https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ytn.co.kr&amp;client=NEWS_360&amp;size=96&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL 2x"/><div class="a7P8l"><div class="vr1PYe" data-n-tid="9">YTN</div></div></div><div class="hLNLFf JfXTR"><div jsaction="TDui6d:BgNF9e;EDR5Je:s1jPxd;dcnbp:ZElhof;FzgWvd:RmtIce;" jscontroller="edeRg" jsdata="oM6qxc;CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNV8yMDI0MDUwNDA2MjkzNTk1NTHSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDVfMjAyNDA1MDQwNjI5MzU5NTUx;4" jslog="109017; track:click" jsmodel="DBqG5"><div class="VfPpkd-xl07Ob-XxIAqe-OWXEXe-oYxtQd" data-is-menu-dynamic="true" jsaction="JIbuQc:aj0Jcf(WjL7X); keydown:uYT2Vb(WjL7X);xDliB:oNPcuf;SM8mFd:li9Srb;iFFCZc:NSsOUb;Rld2oe:NSsOUb" jscontroller="wg1P6b" jsname="Li8BO" jsshadow=""><div jsname="WjL7X" jsslot=""><span data-is-tooltip-wrapper="true"><button aria-expanded="false" aria-haspopup="menu" aria-label="더보기 - 코로나19·사스·메르스, 인체 감염 전략 각기 달랐다" class="VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud" data-idom-class="yHy1rc eT1oJ mN1ivc hUJSud" data-n-tid="27" data-tooltip-enabled="true" data-tooltip-id="tt-i10" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;" jscontroller="soHxf"><div class="VfPpkd-Bz112c-Jh9lGc" jsname="s3Eaab"></div><div class="VfPpkd-Bz112c-J1Ukfc-LhBDec"></div><span aria-hidden="true" class="VfPpkd-kBDsod"><svg class="NMm5M" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M12 8c1.1 0 2-.9 2-2s-.9-2- ...

# %%
## news_items 에서 각 뉴스의 링크, 제목, 내용, 출처, 등록일시 등 추출:
## title
news_items[0].find('div', attrs={'class':'XlKvRb'}).text
# Out:
# ''

# %%
## content
news_items[1].find('a', attrs={'class':'WwrzSb'}).text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [175], in <cell line: 2>()
#       1 ## content
# ----> 2 news_items[1].find('a', attrs={'class':'WwrzSb'}).text
#
# IndexError: list index out of range

# %%
## register
news_items[0].find('div', attrs={'class':'MgUUmf NUnG9d'}).text
# Out:
# 'YTN'

# %%
## time
news_items[0].find('div', attrs={'class':'OSrXXb rbYSKb LfVVr'}).text
# Out:
# '9시간 전'

# %%
## datetime
#news_items[0].find('time', attrs={'class':'WW6dff uQIVzc Sksgp'})
#news_items[0].find('time', attrs={'class':'WW6dff uQIVzc Sksgp'}).get('datetime')
#news_items[0].find('time', attrs={'class':'WW6dff uQIVzc Sksgp'}).get('datetime').split('T')

# %% [markdown]
# ### 실습 (2) google news 검색 함수 작성
#
#  - 실습(1) 활용하여 검색어 직접 입력하여 구글 뉴스 스크래핑 작성

# %%
# 패키지 import
import requests
from bs4 import BeautifulSoup
import urllib

# %%
# 검색어 요청 :
input_word = input('검색어 입력 : ')
# Out:
# 검색어 입력 : 코로나

# %%
input_word
# Out:
# '코로나'

# %% [markdown]
# - (cf) urllib.parse.quote()는 아스키코드 형식이 아닌 글자를 URL 인코딩 시켜줍니다
#
# (참고) URL 변환기 : https://www.convertstring.com/ko/EncodeDecode/UrlEncode

# %%
## Google news 검색어 URL 코드로 encoding:
urllib.parse.quote(input_word)
# Out:
# '%EC%BD%94%EB%A1%9C%EB%82%98'

# %%
# 검색어 정보 URL 구성:
base_url = "https://news.google.com"
keyword = urllib.parse.quote(input_word)
search_url = "/search?q=" + keyword + "&hl=ko&gl=KR&ceid=KR%3Ako"  # keyword: %EC%BD%94%EB%A1%9C%EB%82%98
url = base_url + search_url
print(url)
# Out:
# https://news.google.com/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako

# %% [markdown]
# #### def 함수화 시켜봅시다.

# %%
def google_news_clipping_keyword(keyword_input):
    base_url = "https://news.google.com"
    keyword = urllib.parse.quote(keyword_input)
    search_url = "/search?q=" + keyword + "&hl=ko&gl=KR&ceid=KR%3Ako"  # keyword: %EC%BD%94%EB%A1%9C%EB%82%98
    url = base_url + search_url
    
    return url

# %%
# 함수를 실행하여 뉴스 목록 정리
search_word = input("검색어를 입력하세요: ")
# Out:
# 검색어를 입력하세요: 코로나

# %%
news = google_news_clipping_keyword(search_word)

# %%
print(news)
# Out:
# https://news.google.com/search?q=%EC%BD%94%EB%A1%9C%EB%82%98&hl=ko&gl=KR&ceid=KR%3Ako

# %%
import requests
from bs4 import BeautifulSoup

# 웹페이지 주소
url_ggl = url

# HTTP GET 요청 보내기
response = requests.get(url_ggl)

# 요청이 성공했는지 확인
if response.status_code == 200:
    # HTML 문서 파싱
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 기사 제목 추출
    headlines = soup.find_all('div', class_='n0jPhd')
    print(headlines)
    # 기사 제목 출력
    for index, headline in enumerate(headlines, start=1):
        print(f"{index}. {headline.text}")
else:
    print("Failed to retrieve the webpage.")
# Out:
# []
